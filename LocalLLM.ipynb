# %% [markdown]
# RUNNING LLM MODEL LOCALY

# %% [markdown]
# - INSTALL OLAMMA

# %% [markdown]
# Ollama is a lightweight framework that allows you to run large language models (LLMs) locally on your computer with minimal setup. It simplifies downloading, running, and managing open-source models like Mistral, LLaMA, Gemma, and more—without needing cloud APIs.

# %% [markdown]
# FOR WINDOWS DOWNLOAD OLLAMA FROM [ https://ollama.com/download/windows ]

# %% [markdown]
# CHECK OLLAMA

# %%
# !ollama
# Out:
# Usage:
#   ollama [flags]
#   ollama [command]
#
# Available Commands:
#   serve       Start ollama
#   create      Create a model from a Modelfile
#   show        Show information for a model
#   run         Run a model
#   stop        Stop a running model
#   pull        Pull a model from a registry
#   push        Push a model to a registry
#   list        List models
#   ps          List running models
#   cp          Copy a model
#   rm          Remove a model
#   help        Help about any command
#
# Flags:
#   -h, --help      help for ollama
#   -v, --version   Show version information
#
# Use "ollama [command] --help" for more information about a command.

# %%
# !ollama --version
# Out:
# ollama version is 0.5.12

# %% [markdown]
# SERVE OLLAMA IN SEPERATE TERMINAL TO TEST IT

# %%
# !ollama serve
# Out:
# Couldn't find '/root/.ollama/id_ed25519'. Generating new private key.
# Your new public key is:
#
# ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAIC9gYMJ8H3vbWpZtOkhqCrEg8wPNcETMl8Oci6gVuWRA
#
# ...

# %%
# !ollama list
# Out:
# NAME                       ID              SIZE      MODIFIED
# llama3.1:8b                46e0c10c039e    4.9 GB    2 months ago
# nomic-embed-text:latest    0a109f422b47    274 MB    2 months ago

# %%
# !ollama pull tinyllama
# Out:
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling ma
# ...

# %% [markdown]
# run ollama run [modelname/id] to run the model we can start it in another terminal

# %%
import requests

url = "http://localhost:11434/api/generate"

model_id = "llama3.1:8b"


payload = {
    "model": model_id,  
    "prompt": "Explain quantum computing in simple terms.",
    "stream": False
}


response = requests.post(url, json=payload)

response_data = response.json()
if "response" in response_data:
    print(response_data["response"])
else:
    print("Unexpected Response:", response_data)
# Out:
# Quantum computing can be a bit mind-bending, but I'll try to explain it in simple terms.
#
# **Classical Computing vs. Quantum Computing**
#
# You're probably familiar with classical computers, like your smartphone or laptop. They use "bits" to store and process information. A bit is either 0 or 1, like a light switch that's either on (1) or off (0). Classical computers use these bits to perform calculations and solve problems.
#
# Quantum computing is different. It uses "qubits" (quantum bits), which are special kinds of particles that can exist in many states at the same time! This is where things get weird and cool.
#
# **Qubits: The Magic of Superposition**
#
# Imagine a coin that's either heads or tails, but not both at the same time. That's like a classical bit. But with qubits, it's like having a coin that can be:
#
# * Heads
# * Tails
# * Both heads and tails (simultaneously!)
# * And even exist in many states in between
#
# ...

# %% [markdown]
# ## to give model access to all systems in our lan we have to serve ollama as OLLAMA_HOST=0.0.0.0 ollama serve
