# %% [markdown]
# ##### Copyright 2024 Google LLC.

# %%
# !pip install -U -q google-generativeai
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import textwrap
import numpy as np
import pandas as pd

import google.generativeai as genai



from IPython.display import Markdown

# %%
# Or use `os.getenv('API_KEY')` to fetch an environment variable.

import google.generativeai as genai

# Set your API key manually
GOOGLE_API_KEY = "AIzaSyDEWge2PzWvKDCLHkPFhD4xdsvB7GPSqss"
genai.configure(api_key=GOOGLE_API_KEY)

# %% [markdown]
# Key Point: Next, you will choose a model. Any embedding model will work for this tutorial, but for real applications it's important to choose a specific model and stick with it. The outputs of different models are not compatible with each other.
#
# **Note**: At this time, the Gemini API is [only available in certain regions](https://ai.google.dev/gemini-api/docs/available-regions).

# %%
for m in genai.list_models():
  if 'embedContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/embedding-001
# models/text-embedding-004

# %%
model = 'models/embedding-001'
embedding = genai.embed_content(model=model,
                                content="jvhiyhighjihiyhgkiuh",
                                task_type="retrieval_document",
                                title="title")

print(embedding)
# Out:
# {'embedding': [0.022285031, 0.006432155, -0.051558062, -0.035611223, 0.05828589, 0.025274409, 0.03630779, -0.0007751998, -0.014323384, 0.051769305, -0.01888757, -0.0109815085, -0.042532813, 0.014663985, 0.00230979, -0.013360447, 0.02633334, -0.00234763, 0.028458158, -0.0071547227, -0.016558176, 0.010666258, -0.022199009, -0.040127497, 0.017608069, -0.024883412, 0.013067426, -0.03489601, -0.032509234, -0.013983085, -0.012554802, 0.0021771942, -0.061531052, 0.00518471, 0.022047464, -0.06869267, 0.0021179556, -0.007148818, 0.021522304, 0.018251022, 0.023489838, -0.0069533726, -0.033541355, 0.011370304, 0.01797465, 0.016786432, -0.034509867, 0.028804654, 0.012110709, -0.060457814, 0.026449282, 0.027039526, 0.0889816, -0.025439387, -0.025371859, -0.017466009, 0.05213288, 0.019027468, -0.04672284, 0.039657682, -0.022967376, -0.0034840596, 0.035442337, -0.014047184, -0.0419975, -0.046768572, -0.030109633, 0.022686193, 0.06764761, -0.00010029963, -0.04032826, -0.057085663, 0.026000096, -0.018273527, -0.0065218722, -0.1355047, -0.0029036026, 0.068146855, 0.018286094, -0.0089691095, -0.011246227, -0.042180736, -0.06833888, -0.032739624, -0.06968203, 0.028031444, -0.05195537, -0.018317359, 0.022137599, 0.028153837, -0.03250205, -0.034206677, 0.06408105, -0.04431628, 0.003912761, 0.07249659, -0.01969988, -0.02081892, 0.028156415, -0.004233302, 0.0027234587, -0.01926681, -0.041554462, 0.025813747, 0.050578754, 0.014948011, 0.012585209, 0.024139661, -0.012646576, 0.011660061, -0.064565964, 0.016052512, 0.0069064363, -0.01292915, 0.026241593, -0.030942038, -0.0051234337, 0.054859627, 0.036724977, 0.047401216, 0.040560722, -0.030068263, 0.05415517, -0.005248672, 0.028237542, 0.030562462, -0.011026125, 0.0660041, 0.02545028, 0.013819855, -0.016536895, -0.056129888, -0.035832725, 0.042208582, 0.042930767, 0.06782771, 0.023812996, -0.015912766, 0.027097838, -0.008932486, -0.0017486105, 0.013791425, 0.005765702, 0.050782118, -0.014585695, 0.04202194, -0.06539487, 0.0114768855, 0.04627314, -0.023482613, -0.0027467674, -0.023954246, -0.055859327, -0.0142859435, 0.085335, -0.0028728223, -0.008546934, 0.04132801, 0.013692759, -0.019763922, 0.022963775, -0.006845039, 0.012473686, 0.023891032, -0.024975816, -0.01685904, -0.008743308, -0.0063952385, -0.0022293653, 0.051284246, -0.025003193, 0.041433662, -0.044668373, -0.04183771, -0.029482175, -0.041090272, 0.009090841, 0.009152074, -0.022252852, 0.0049786684, 0.02384866, -0.03520888, 0.02350872, 0.034407835, 0.030230444, -0.047822874, 0.08961626, 0.029264916, -0.025827488, 0.028153917, -0.018152399, 0.0063099544, -0.05725358, -0.027702896, -0.039808474, 0.051715657, 0.004633714, 0.008215983, -0.018210633, -0.039051253, 0.012518315, 0.04295761, -0.024692671, 0.0029754103, 0.010871305, -0.010663399, 0.069322586, -0.062356595, -0.034760337, 0.008962699, -0.0025027376, 0.011986113, 0.002806416, 0.018545644, 0.029619843, -0.010229926, 0.022733318, 0.042680006, 0.021083344, -0.008234877, -0.011482435, 0.021710044, -0.020698851, 0.011178763, -0.0055768183, 0.03516677, -0.0084784515, 0.038663074, 0.026588216, -0.04956922, -0.010929027, 0.06823911, 0.027517887, -0.011261982, 0.08760754, 0.0044865515, 0.012551054, 0.024507944, 0.022060074, 0.046897896, -0.034967043, 0.026871005, 0.03599044, 0.025877172, -0.062148917, -0.041879088, -0.04607982, 0.023152132, 0.0074231504, 0.0691073, -0.0067881476, -0.03687102, -0.016214568, -0.00021700977, -0.10148416, 0.031401023, -0.044419065, 0.05369807, -0.024340875, -0.0050190715, 0.05597449, -0.0034100488, -0.019866051, -0.016188715, -0.010153375, -0.0027516875, -0.010447297, -0.086149335, -0.01505407, -0.0012348086, 0.0113339145, -0.013342269, 0.05765907, -0.0016910357, -0.015080831, 0.0024290795, -0.019252542, 0.07468401, 0.011471227, -0.039438702, 0.022997491, 0.058120567, 0.034125, -0.037582543, -0.012066466, 0.004823584, -0.07111004, -0.051484823, 0.026919795, -0.033224333, -0.04172557, -0.06392535, 0.028722795, -0.047801092, -0.041502297, 0.0103646135, -0.012797335, 0. ...

# %% [markdown]
# Organize the contents of the dictionary into a dataframe for better visualization.

# %% [markdown]
# Get the embeddings for each of these bodies of text. Add this information to the dataframe.

# %%
import json

# %%
import json

# Load JSON file
with open('data.json', 'r') as f:
    data = json.load(f)  # Load JSON list

text_data=dict()
# Traverse and print each document as a JSON string
i=1
for doc in data:
    json_str = json.dumps(doc)  # Convert dictionary to JSON string
    text_data[i]=json_str[1:-1]
    print(text_data[i])
    i+=1
# Out:
# "Ages": 25, "Gender": "Male", "Height": 180, "Weight": 80, "Activity Level": "Moderately Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 2000, "Protein": 120, "Sugar": 125.0, "Sodium": 24.0, "Calories": 2020, "Carbohydrates": 250, "Fiber": 30.0, "Fat": 60, "Breakfast Suggestion": "Oatmeal with berries and nuts", "Breakfast Calories": 320.0, "Breakfast Protein": 15.0, "Breakfast Carbohydrates": 48.0, "Breakfast Fats": 12.0, "Lunch Suggestion": "Grilled chicken salad with mixed greens", "Lunch Calories": 250.0, "Lunch Protein": 26.0, "Lunch Carbohydrates": 26.0, "Dinner Suggestion": "Salmon with roasted vegetables", "Dinner Calories": 2020.0, "Dinner Protein.1": 60.0, "Dinner Carbohydrates.1": 250.0, "Dinner Fats": 60.0, "Snack Suggestion": "Greek yogurt with fruit", "Snacks Calories": 150, "Snacks Protein": 10, "Snacks Carbohydrates": 20, "Snacks Fats": 5, "Disease": "Weight Gain", "Lunch Fats": 12
# "Ages": 32, "Gender": "Female", "Height": 165, "Weight": 65, "Activity Level": "Lightly Active", "Dietary Preference": "Vegetarian", "Daily Calorie Target": 1600, "Protein": 80, "Sugar": 100.0, "Sodium": 16.0, "Calories": 1480, "Carbohydrates": 200, "Fiber": 24.0, "Fat": 40, "Breakfast Suggestion": "Tofu scramble with veggies", "Breakfast Calories": 189.0, "Breakfast Protein": 36.0, "Breakfast Carbohydrates": 15.0, "Breakfast Fats": 3.5, "Lunch Suggestion": "Lentil soup with whole wheat bread", "Lunch Calories": 269.0, "Lunch Protein": 36.0, "Lunch Carbohydrates": 9.0, "Dinner Suggestion": "Vegetable stir-fry with brown rice", "Dinner Calories": 10.0, "Dinner Protein.1": 5.0, "Dinner Carbohydrates.1": 31.0, "Dinner Fats": 27.0, "Snack Suggestion": "Apple with almond butter", "Snacks Calories": 180, "Snacks Protein": 4, "Snacks Carbohydrates": 30, "Snacks Fats": 8, "Disease": "Weight Gain, Hypertension, Heart Disease", "Lunch Fats": 8
# "Ages": 48, "Gender": "Male", "Height": 175, "Weight": 95, "Activity Level": "Sedentary", "Dietary Preference": "Vegan", "Daily Calorie Target": 2200, "Protein": 100, "Sugar": 150.0, "Sodium": 20.0, "Calories": 2185, "Carbohydrates": 300, "Fiber": 36.0, "Fat": 65, "Breakfast Suggestion": "Tofu and veggie breakfast burrito", "Breakfast Calories": 226.0, "Breakfast Protein": 20.0, "Breakfast Carbohydrates": 70.0, "Breakfast Fats": 4.0, "Lunch Suggestion": "Black bean burger on a whole wheat bun", "Lunch Calories": 171.0, "Lunch Protein": 57.0, "Lunch Carbohydrates": 32.0, "Dinner Suggestion": "Lentil and vegetable curry", "Dinner Calories": 326.0, "Dinner Protein.1": 55.0, "Dinner Carbohydrates.1": 150.0, "Dinner Fats": 15.0, "Snack Suggestion": "Trail mix", "Snacks Calories": 300, "Snacks Protein": 8, "Snacks Carbohydrates": 34, "Snacks Fats": 20, "Disease": "Weight Gain", "Lunch Fats": 15
# "Ages": 55, "Gender": "Female", "Height": 160, "Weight": 70, "Activity Level": "Very Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 2500, "Protein": 140, "Sugar": 175.0, "Sodium": 28.0, "Calories": 2680, "Carbohydrates": 350, "Fiber": 42.0, "Fat": 80, "Breakfast Suggestion": "Greek yogurt with granola and fruit", "Breakfast Calories": 283.0, "Breakfast Protein": 14.0, "Breakfast Carbohydrates": 44.0, "Breakfast Fats": 20.0, "Lunch Suggestion": "Chicken and vegetable stir-fry", "Lunch Calories": 578.0, "Lunch Protein": 43.0, "Lunch Carbohydrates": 62.0, "Dinner Suggestion": "Turkey chili with brown rice", "Dinner Calories": 278.0, "Dinner Protein.1": 20.0, "Dinner Carbohydrates.1": 163.0, "Dinner Fats": 27.0, "Snack Suggestion": "Banana with peanut butter", "Snacks Calories": 210, "Snacks Protein": 5, "Snacks Carbohydrates": 30, "Snacks Fats": 9, "Disease": "Weight Gain", "Lunch Fats": 10
# "Ages": 62, "Gender": "Male", "Height": 170, "Weight": 85, "Activity Level": "Sedentary", "Dietary Preference": "Vegetarian", "Daily Calorie Target": 2000, "Protein": 80, "Sugar": 125.0, "Sodium": 16.0, "Calories": 1815, "Carbohydrates": 250, "Fiber": 30.0, "Fat": 55, "Breakfast Suggestion": "Scrambled eggs with whole wheat toast and avocado", "Breakfast Calories": 133.0, "Breakfast Protein": 12.0, "Breakfast Carbohydrates": 22.0, "Breakfast Fats": 1.0, "Lunch Suggestion": "Quinoa salad with chickpeas and vegetables", "Lunch Calories": 492.0, "Lunch Protein": 10.0, "Lunch Carbohydrates": 47.0, "Dinner Suggestion": "Vegetarian chili with cornbread", "Dinner Calories": 186.0, "Dinner Protein.1": 6.3, "Dinner Carbohydrates.1": 186.0, "Dinner Fats": 22.0, "Snack Suggestion": "Fruit and nut mix", "Snacks Calories": 250, "Snacks Protein": 6, "Snacks Carbohydrates": 28, "Snacks Fats": 15, "Disease": "Weight Gain", "Lunch Fats": 9
# "Ages": 68, "Gender": "Female", "Height": 155, "Weight": 60, "Activity Level": "Lightly Active", "Dietary Preference": "Vegan", "Daily Calorie Target": 1800, "Protein": 70, "Sugar": 110.0, "Sodium": 14.0, "Calories": 1565, "Carbohydrates": 220, "Fiber": 26.4, "Fat": 45, "Breakfast Suggestion": "Tofu scramble with veggies", "Breakfast Calories": 272.8, "Breakfast Protein": 7.0, "Breakfast Carbohydrates": 45.0, "Breakfast Fats": 17.0, "Lunch Suggestion": "Lentil pasta with vegetables", "Lunch Calories": 502.0, "Lunch Protein": 34.0, "Lunch Carbohydrates": 22.0, "Dinner Suggestion": "Vegan stir-fry with brown rice", "Dinner Calories": 17.0, "Dinner Protein.1": 5.0, "Dinner Carbohydrates.1": 22.0, "Dinner Fats": 43.0, "Snack Suggestion": "Hummus and veggie wrap", "Snacks Calories": 200, "Snacks Protein": 7, "Snacks Carbohydrates": 25, "Snacks Fats": 10, "Disease": "Weight Gain, Hypertension, Heart Disease, Kidney Disease", "Lunch Fats": 7
# "Ages": 28, "Gender": "Male", "Height": 190, "Weight": 100, "Activity Level": "Moderately Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 3000, "Protein": 180, "Sugar": 175.0, "Sodium": 36.0, "Calories": 2840, "Carbohydrates": 350, "Fiber": 42.0, "Fat": 80, "Breakfast Suggestion": "Protein pancakes with fruit and nuts", "Breakfast Calories": 296.0, "Breakfast Protein": 27.0, "Breakfast Carbohydrates": 29.0, "Breakfast Fats": 24.0, "Lunch Suggestion": "Chicken breast with brown rice and vegetables", "Lunch Calories": 270.0, "Lunch Protein": 24.0, "Lunch Carbohydrates": 19.0, "Dinner Suggestion": "Steak with sweet potato and broccoli", "Dinner Calories": 730.0, "Dinner Protein.1": 21.0, "Dinner Carbohydrates.1": 72.0, "Dinner Fats": 54.0, "Snack Suggestion": "Protein shake", "Snacks Calories": 200, "Snacks Protein": 20, "Snacks Carbohydrates": 10, "Snacks Fats": 5, "Disease": "Weight Gain", "Lunch Fats": 11
# "Ages": 35, "Gender": "Female", "Height": 170, "Weight": 75, "Activity Level": "Very Active", "Dietary Preference": "Vegetarian", "Daily Calorie Target": 2400, "Protein": 120, "Sugar": 150.0, "Sodium": 24.0, "Calories": 2220, "Carbohydrates": 300, "Fiber": 36.0, "Fat": 60, "Breakfast Suggestion": "Tofu and veggie breakfast burrito", "Breakfast Calories": 149.0, "Breakfast Protein": 14.0, "Breakfast Carbohydrates": 41.0, "Breakfast Fats": 11.0, "Lunch Suggestion": "Black bean burger on a whole wheat bun", "Lunch Calories": 648.0, "Lunch Protein": 40.0, "Lunch Carbohydrates": 35.0, "Dinner Suggestion": "Quinoa and vegetable bowl", "Dinner Calories": 294.0, "Dinner Protein.1": 27.0, "Dinner Carbohydrates.1": 30.0, "Dinner Fats": 11.0, "Snack Suggestion": "Cottage cheese with fruit", "Snacks Calories": 160, "Snacks Protein": 14, "Snacks Carbohydrates": 12, "Snacks Fats": 5, "Disease": "Weight Gain", "Lunch Fats": 15
# "Ages": 42, "Gender": "Male", "Height": 185, "Weight": 110, "Activity Level": "Moderately Active", "Dietary Preference": "Vegan", "Daily Calorie Target": 3200, "Protein": 160, "Sugar": 200.0, "Sodium": 32.0, "Calories": 3005, "Carbohydrates": 400, "Fiber": 48.0, "Fat": 85, "Breakfast Suggestion": "Tofu and chickpea scramble", "Breakfast Calories": 289.0, "Breakfast Protein": 20.0, "Breakfast Carbohydrates": 42.0, "Breakfast Fats": 25.0, "Lunch Suggestion": "Lentil burger with sweet potato fries", "Lunch Calories": 670.0, "Lunch Protein": 50.0, "Lunch Carbohydrates": 45.0, "Dinner Suggestion": "Vegan chili with cornbread", "Dinner Calories": 390.0, "Dinner Protein.1": 4.0, "Dinner Carbohydrates.1": 45.0, "Dinner Fats": 8.0, "Snack Suggestion": "Energy bar", "Snacks Calories": 220, "Snacks Protein": 10, "Snacks Carbohydrates": 25, "Snacks Fats": 8, "Disease": "Weight Gain", "Lunch Fats": 14
# "Ages": 58, "Gender": "Female", "Height": 168, "Weight": 78, "Activity Level": "Sedentary", "Dietary Preference": "Vegan", "Daily Calorie Target": 1900, "Protein": 75, "Sugar": 115.0, "Sodium": 15.0, "Calories": 1670, "Carbohydrates": 230, "Fiber": 27.6, "Fat": 50, "Breakfast Suggestion": "Overnight oats with fruit and chia seeds", "Breakfast Calories": 561.0, "Breakfast Protein": 11.0, "Breakfast Carbohydrates": 53.0, "Breakfast Fats": 7.0, "Lunch Suggestion": "Lentil soup with whole wheat bread", "Lunch Calories": 1670.0, "Lunch Protein": 40.4, "Lunch Carbohydrates": 230.0, "Dinner Suggestion": "Vegan pasta with vegetables and sauce", "Dinner Calories": 1670.0, "Dinner Protein.1": 40.4, "Dinner Carbohydrates.1": 47.5, "Dinner Fats": 50.0, "Snack Suggestion": "Fruit and veggie sticks", "Snacks Calories": 100, "Snacks Protein": 2, "Snacks Carbohydrates": 20, "Snacks Fats": 1, "Disease": "Weight Gain, Kidney Disease", "Lunch Fats": 8
# "Ages": 25, "Gender": "Male", "Height": 180, "Weight": 80, "Activity Level": "Lightly Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 2000, "Protein": 120, "Sugar": 125.0, "Sodium": 24.0, "Calories": 2020, "Carbohydrates": 250, "Fiber": 30.0, "Fat": 60, "Breakfast Suggestion": "Oatmeal with berries and nuts", "Breakfast Calories": 399.0, "Breakfast Protein": 54.0, "Breakfast Carbohydrates": 56.0, "Breakfast Fats": 14.0, "Lunch Suggestion": "Grilled chicken salad with mixed greens", "Lunch Calories": 335.0, "Lunch Protein": 10.3, "Lunch Carbohydrates": 8.6, "Dinner Suggestion": "Salmon with roasted vegetables", "Dinner Calories": 610.0, "Dinner Protein.1": 48.0, "Dinner Carbohydrates.1": 59.0, "Dinner Fats": 21.6, "Snack Suggestion": "Greek yogurt with fruit", "Snacks Calories": 150, "Snacks Protein": 10, "Snacks Carbohydrates": 20, "Snacks Fats": 5, "Disease": "Weight Gain", "Lunch Fats": 12
# "Ages": 32, "Gender": "Female", "Height": 165, "Weight": 65, "Activity Level": "Moderately Active", "Dietary Preference": "Vegan", "Daily Calorie Target": 2200, "Protein": 100, "Sugar": 150.0, "Sodium": 20.0, "Calories": 2230, "Carbohydrates": 300, "Fiber": 36.0, "Fat": 70, "Breakfast Suggestion": "Tofu scramble with vegetables", "Breakfast Calories": 219.0, "Breakfast Protein": 21.0, "Breakfast Carbohydrates": 25.0, "Breakfast Fats": 3.0, "Lunch Suggestion": "Lentil soup with wholegrain bread", "Lunch Calories": 137.0, "Lunch Protein": 4.0, "Lunch Carbohydrates": 72.0, "Dinner Suggestion": "Chickpea and vegetable curry", "Dinner Calories": 710.0, "Dinner Protein.1": 28.0, "Dinner Carbohydrates.1": 300.0, "Dinner Fats": 29.0, "Snack Suggestion": "Trail mix with nuts and seeds", "Snacks Calories": 350, "Snacks Protein": 10, "Snacks Carbohydrates": 40, "Snacks Fats": 25, "Disease": "Weight Gain", "Lunch Fats": 8
# "Ages": 48, "Gender": "Male", "Height": 175, "Weight": 95, "Activity Level": "Sedentary", "Dietary Preference": "Vegetarian", "Daily Calorie Target": 2400, "Protein": 100, "Sugar": 175.0, "Sodium": 20.0, "Calories": 2520, "Carbohydrates": 350, "Fiber": 42.0, "Fat": 80, "Breakfast Suggestion": "Wholegrain toast with avocado", "Breakfast Calories": 285.0, "Breakfast Protein": 8.5, "Breakfast Carbohydrates": 47.0, "Breakfast Fats": 24.0, "Lunch Suggestion": "Black bean salad", "Lunch Calories": 535.0, "Lunch Protein": 22.0, "Lunch Carbohydrates": 35.0, "Dinner Suggestion": "Vegetable stir-fry with tofu", "Dinner Calories": 597.0, "Dinner Protein.1": 3.4, "Dinner Carbohydrates.1": 59.0, "Dinner Fats": 25.0, "Snack Suggestion": "Fruit salad with yogurt", "Snacks Calories": 150, "Snacks Protein": 4, "Snacks Carbohydrates": 25, "Snacks Fats": 7, "Disease": "Weight Gain", "Lunch Fats": 6
# "Ages": 55, "Gender": "Female", "Height": 160, "Weight": 70, "Activity Level": "Moderately Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 1800, "Protein": 100, "Sugar": 100.0, "Sodium": 20.0, "Calories": 1650, "Carbohydrates": 200, "Fiber": 24.0, "Fat": 50, "Breakfast Suggestion": "Greek yogurt with granola", "Breakfast Calories": 308.0, "Breakfast Protein": 19.0, "Breakfast Carbohydrates": 40.0, "Breakfast Fats": 3.0, "Lunch Suggestion": "Tuna salad sandwich on wholegrain bread", "Lunch Calories": 570.0, "Lunch Protein": 31.0, "Lunch Carbohydrates": 25.0, "Dinner Suggestion": "Chicken breast with steamed vegetables", "Dinner Calories": 100.0, "Dinner Protein.1": 31.0, "Dinner Carbohydrates.1": 28.0, "Dinner Fats": 31.0, "Snack Suggestion": "Popcorn", "Snacks Calories": 100, "Snacks Protein": 3, "Snacks Carbohydrates": 15, "Snacks Fats": 5, "Disease": "Weight Gain", "Lunch Fats": 13
# "Ages": 62, "Gender": "Male", "Height": 170, "Weight": 85, "Activity Level": "Very Active", "Dietary Preference": "Vegan", "Daily Calorie Target": 3000, "Protein": 150, "Sugar": 200.0, "Sodium": 30.0, "Calories": 3100, "Carbohydrates": 400, "Fiber": 48.0, "Fat": 100, "Breakfast Suggestion": "Tofu and vegetable stir-fry", "Breakfast Calories": 374.0, "Breakfast Protein": 7.9, "Breakfast Carbohydrates": 9.0, "Breakfast Fats": 3.4, "Lunch Suggestion": "Lentil and vegetable stew", "Lunch Calories": 316.0, "Lunch Protein": 30.0, "Lunch Carbohydrates": 68.0, "Dinner Suggestion": "Vegan chili", "Dinner Calories": 500.0, "Dinner Protein.1": 28.0, "Dinner Carbohydrates.1": 140.0, "Dinner Fats": 7.0, "Snack Suggestion": "Smoothie with protein powder", "Snacks Calories": 200, "Snacks Protein": 20, "Snacks Carbohydrates": 30, "Snacks Fats": 2, "Disease": "Weight Gain", "Lunch Fats": 9
# "Ages": 28, "Gender": "Female", "Height": 172, "Weight": 60, "Activity Level": "Lightly Active", "Dietary Preference": "Vegan", "Daily Calorie Target": 2000, "Protein": 100, "Sugar": 125.0, "Sodium": 20.0, "Calories": 1940, "Carbohydrates": 250, "Fiber": 30.0, "Fat": 60, "Breakfast Suggestion": "Tofu scramble with vegetables", "Breakfast Calories": 501.0, "Breakfast Protein": 20.0, "Breakfast Carbohydrates": 52.0, "Breakfast Fats": 2.0, "Lunch Suggestion": "Black bean burger on a wholegrain bun", "Lunch Calories": 395.0, "Lunch Protein": 32.0, "Lunch Carbohydrates": 60.0, "Dinner Suggestion": "Lentil pasta with vegetables", "Dinner Calories": 715.0, "Dinner Protein.1": 19.0, "Dinner Carbohydrates.1": 11.0, "Dinner Fats": 44.0, "Snack Suggestion": "Trail mix with nuts and seeds", "Snacks Calories": 350, "Snacks Protein": 10, "Snacks Carbohydrates": 40, "Snacks Fats": 25, "Disease": "Weight Gain", "Lunch Fats": 15
# "Ages": 35, "Gender": "Male", "Height": 185, "Weight": 90, "Activity Level": "Very Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 2500, "Protein": 150, "Sugar": 150.0, "Sodium": 30.0, "Calories": 2520, "Carbohydrates": 300, "Fiber": 36.0, "Fat": 80, "Breakfast Suggestion": "Oatmeal with protein powder and fruit", "Breakfast Calories": 250.0, "Breakfast Protein": 34.0, "Breakfast Carbohydrates": 49.0, "Breakfast Fats": 25.0, "Lunch Suggestion": "Grilled chicken breast with brown rice", "Lunch Calories": 735.0, "Lunch Protein": 79.0, "Lunch Carbohydrates": 328.0, "Dinner Suggestion": "Salmon with roasted vegetables", "Dinner Calories": 624.0, "Dinner Protein.1": 48.0, "Dinner Carbohydrates.1": 53.0, "Dinner Fats": 40.0, "Snack Suggestion": "Fruit and nuts", "Snacks Calories": 180, "Snacks Protein": 6, "Snacks Carbohydrates": 30, "Snacks Fats": 8, "Disease": "Weight Gain", "Lunch Fats": 10
# "Ages": 40, "Gender": "Female", "Height": 168, "Weight": 75, "Activity Level": "Moderately Active", "Dietary Preference": "Vegetarian", "Daily Calorie Target": 2200, "Protein": 100, "Sugar": 150.0, "Sodium": 20.0, "Calories": 2230, "Carbohydrates": 300, "Fiber": 36.0, "Fat": 70, "Breakfast Suggestion": "Wholegrain toast with avocado", "Breakfast Calories": 215.0, "Breakfast Protein": 10.8, "Breakfast Carbohydrates": 67.0, "Breakfast Fats": 21.0, "Lunch Suggestion": "Lentil soup with wholegrain bread", "Lunch Calories": 628.0, "Lunch Protein": 55.0, "Lunch Carbohydrates": 37.0, "Dinner Suggestion": "Vegetable stir-fry with tofu", "Dinner Calories": 501.0, "Dinner Protein.1": 10.0, "Dinner Carbohydrates.1": 54.0, "Dinner Fats": 48.0, "Snack Suggestion": "Fruit salad with yogurt", "Snacks Calories": 150, "Snacks Protein": 4, "Snacks Carbohydrates": 25, "Snacks Fats": 7, "Disease": "Weight Gain", "Lunch Fats": 8
# "Ages": 22, "Gender": "Male", "Height": 190, "Weight": 100, "Activity Level": "Lightly Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 2800, "Protein": 160, "Sugar": 175.0, "Sodium": 32.0, "Calories": 2850, "Carbohydrates": 350, "Fiber": 42.0, "Fat": 90, "Breakfast Suggestion": "Eggs with wholegrain toast", "Breakfast Calories": 304.0, "Breakfast Protein": 14.0, "Breakfast Carbohydrates": 39.0, "Breakfast Fats": 50.0, "Lunch Suggestion": "Chicken breast with brown rice", "Lunch Calories": 667.0, "Lunch Protein": 62.0, "Lunch Carbohydrates": 64.0, "Dinner Suggestion": "Steak with roasted vegetables", "Dinner Calories": 1507.0, "Dinner Protein.1": 93.1, "Dinner Carbohydrates.1": 196.0, "Dinner Fats": 93.1, "Snack Suggestion": "Protein bar", "Snacks Calories": 250, "Snacks Protein": 8, "Snacks Carbohydrates": 30, "Snacks Fats": 12, "Disease": "Weight Gain", "Lunch Fats": 10
# "Ages": 58, "Gender": "Female", "Height": 155, "Weight": 68, "Activity Level": "Sedentary", "Dietary Preference": "Vegan", "Daily Calorie Target": 1600, "Protein": 80, "Sugar": 90.0, "Sodium": 16.0, "Calories": 1400, "Carbohydrates": 180, "Fiber": 21.6, "Fat": 40, "Breakfast Suggestion": "Tofu scramble with vegetables", "Breakfast Calories": 340.0, "Breakfast Protein": 17.0, "Breakfast Carbohydrates": 32.4, "Breakfast Fats": 8.0, "Lunch Suggestion": "Lentil soup with wholegrain bread", "Lunch Calories": 380.0, "Lunch Protein": 22.0, "Lunch Carbohydrates": 68.0, "Dinner Suggestion": "Vegan chili", "Dinner Calories": 400.0, "Dinner Protein.1": 49.0, "Dinner Carbohydrates.1": 87.0, "Dinner Fats": 14.0, "Snack Suggestion": "Fruit and nut mix", "Snacks Calories": 250, "Snacks Protein": 6, "Snacks Carbohydrates": 28, "Snacks Fats": 15, "Disease": "Weight Gain, Hypertension, Heart Disease", "Lunch Fats": 8
# "Ages": 24, "Gender": "Female", "Height": 165, "Weight": 55, "Activity Level": "Lightly Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 1800, "Protein": 100, "Sugar": 125.0, "Sodium": 20.0, "Calories": 1850, "Carbohydrates": 250, "Fiber": 30.0, "Fat": 50, "Breakfast Suggestion": "Greek yogurt with berries and granola", "Breakfast Calories": 465.0, "Breakfast Protein": 24.1, "Breakfast Carbohydrates": 16.8, "Breakfast Fats": 39.0, "Lunch Suggestion": "Salmon salad with mixed greens and avocado", "Lunch Calories": 440.0, "Lunch Protein": 39.0, "Lunch Carbohydrates": 45.0, "Dinner Suggestion": "Chicken stir-fry with brown rice", "Dinner Calories": 510.0, "Dinner Protein.1": 26.0, "Dinner Carbohydrates.1": 52.0, "Dinner Fats": 52.0, "Snack Suggestion": "Apple with peanut butter", "Snacks Calories": 180, "Snacks Protein": 4, "Snacks Carbohydrates": 30, "Snacks Fats": 8, "Disease": "Weight Gain", "Lunch Fats": 18
# "Ages": 38, "Gender": "Male", "Height": 180, "Weight": 80, "Activity Level": "Moderately Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 2800, "Protein": 160, "Sugar": 175.0, "Sodium": 32.0, "Calories": 2760, "Carbohydrates": 350, "Fiber": 42.0, "Fat": 80, "Breakfast Suggestion": "Oatmeal with protein powder and fruit", "Breakfast Calories": 450.0, "Breakfast Protein": 12.4, "Breakfast Carbohydrates": 58.0, "Breakfast Fats": 21.0, "Lunch Suggestion": "Chicken breast with sweet potato and broccoli", "Lunch Calories": 550.0, "Lunch Protein": 25.0, "Lunch Carbohydrates": 25.0, "Dinner Suggestion": "Steak with roasted vegetables", "Dinner Calories": 275.0, "Dinner Protein.1": 6.7, "Dinner Carbohydrates.1": 12.0, "Dinner Fats": 6.0, "Snack Suggestion": "Protein shake", "Snacks Calories": 200, "Snacks Protein": 20, "Snacks Carbohydrates": 10, "Snacks Fats": 5, "Disease": "Weight Gain", "Lunch Fats": 12
# "Ages": 55, "Gender": "Female", "Height": 160, "Weight": 70, "Activity Level": "Sedentary", "Dietary Preference": "Vegetarian", "Daily Calorie Target": 1600, "Protein": 80, "Sugar": 100.0, "Sodium": 16.0, "Calories": 1480, "Carbohydrates": 200, "Fiber": 24.0, "Fat": 40, "Breakfast Suggestion": "Tofu scramble with vegetables", "Breakfast Calories": 148.0, "Breakfast Protein": 10.3, "Breakfast Carbohydrates": 4.0, "Breakfast Fats": 5.6, "Lunch Suggestion": "Lentil soup with whole wheat bread", "Lunch Calories": 426.0, "Lunch Protein": 22.0, "Lunch Carbohydrates": 7.0, "Dinner Suggestion": "Vegetarian chili with brown rice", "Dinner Calories": 219.0, "Dinner Protein.1": 22.0, "Dinner Carbohydrates.1": 23.6, "Dinner Fats": 11.0, "Snack Suggestion": "Trail mix with nuts and dried fruit", "Snacks Calories": 350, "Snacks Protein": 10, "Snacks Carbohydrates": 40, "Snacks Fats": 25, "Disease": "Weight Gain, Hypertension, Heart Disease", "Lunch Fats": 8
# "Ages": 62, "Gender": "Male", "Height": 175, "Weight": 95, "Activity Level": "Moderately Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 2200, "Protein": 120, "Sugar": 140.0, "Sodium": 24.0, "Calories": 2140, "Carbohydrates": 280, "Fiber": 33.6, "Fat": 60, "Breakfast Suggestion": "Eggs with whole wheat toast and avocado", "Breakfast Calories": 250.0, "Breakfast Protein": 27.0, "Breakfast Carbohydrates": 16.0, "Breakfast Fats": 15.6, "Lunch Suggestion": "Turkey sandwich on whole wheat bread with vegetables", "Lunch Calories": 690.0, "Lunch Protein": 57.3, "Lunch Carbohydrates": 41.0, "Dinner Suggestion": "Chicken and vegetable stir-fry with brown rice", "Dinner Calories": 670.0, "Dinner Protein.1": 57.3, "Dinner Carbohydrates.1": 98.0, "Dinner Fats": 26.0, "Snack Suggestion": "Greek yogurt with fruit and granola", "Snacks Calories": 200, "Snacks Protein": 12, "Snacks Carbohydrates": 30, "Snacks Fats": 6, "Disease": "Weight Gain", "Lunch Fats": 11
# "Ages": 28, "Gender": "Female", "Height": 170, "Weight": 65, "Activity Level": "Very Active", "Dietary Preference": "Vegan", "Daily Calorie Target": 2400, "Protein": 140, "Sugar": 160.0, "Sodium": 28.0, "Calories": 2470, "Carbohydrates": 320, "Fiber": 38.4, "Fat": 70, "Breakfast Suggestion": "Tofu scramble with vegetables and avocado", "Breakfast Calories": 240.0, "Breakfast Protein": 18.0, "Breakfast Carbohydrates": 28.0, "Breakfast Fats": 4.0, "Lunch Suggestion": "Vegan lentil stew with whole wheat bread", "Lunch Calories": 440.0, "Lunch Protein": 19.0, "Lunch Carbohydrates": 44.0, "Dinner Suggestion": "Tofu stir-fry with brown rice and vegetables", "Dinner Calories": 411.0, "Dinner Protein.1": 28.0, "Dinner Carbohydrates.1": 44.0, "Dinner Fats": 17.0, "Snack Suggestion": "Banana with almond butter", "Snacks Calories": 210, "Snacks Protein": 5, "Snacks Carbohydrates": 30, "Snacks Fats": 9, "Disease": "Weight Gain", "Lunch Fats": 7
# "Ages": 45, "Gender": "Male", "Height": 185, "Weight": 100, "Activity Level": "Lightly Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 2000, "Protein": 110, "Sugar": 125.0, "Sodium": 22.0, "Calories": 1890, "Carbohydrates": 250, "Fiber": 30.0, "Fat": 50, "Breakfast Suggestion": "Greek yogurt with fruit and granola", "Breakfast Calories": 273.0, "Breakfast Protein": 26.9, "Breakfast Carbohydrates": 40.0, "Breakfast Fats": 1.6, "Lunch Suggestion": "Tuna salad with whole wheat bread", "Lunch Calories": 398.0, "Lunch Protein": 17.2, "Lunch Carbohydrates": 120.0, "Dinner Suggestion": "Chicken breast with sweet potato and green beans", "Dinner Calories": 72.0, "Dinner Protein.1": 28.0, "Dinner Carbohydrates.1": 25.0, "Dinner Fats": 1.6, "Snack Suggestion": "Mixed nuts and seeds", "Snacks Calories": 200, "Snacks Protein": 6, "Snacks Carbohydrates": 20, "Snacks Fats": 15, "Disease": "Weight Gain", "Lunch Fats": 12
# "Ages": 68, "Gender": "Female", "Height": 155, "Weight": 60, "Activity Level": "Sedentary", "Dietary Preference": "Vegan", "Daily Calorie Target": 1400, "Protein": 70, "Sugar": 90.0, "Sodium": 14.0, "Calories": 1315, "Carbohydrates": 180, "Fiber": 21.6, "Fat": 35, "Breakfast Suggestion": "Tofu scramble with vegetables", "Breakfast Calories": 360.0, "Breakfast Protein": 32.0, "Breakfast Carbohydrates": 64.0, "Breakfast Fats": 11.0, "Lunch Suggestion": "Lentil soup with whole wheat bread", "Lunch Calories": 398.0, "Lunch Protein": 43.8, "Lunch Carbohydrates": 44.0, "Dinner Suggestion": "Vegan pasta with vegetables and tomato sauce", "Dinner Calories": 440.0, "Dinner Protein.1": 28.0, "Dinner Carbohydrates.1": 44.0, "Dinner Fats": 22.0, "Snack Suggestion": "Apple with peanut butter", "Snacks Calories": 180, "Snacks Protein": 4, "Snacks Carbohydrates": 30, "Snacks Fats": 8, "Disease": "Weight Gain, Hypertension, Heart Disease, Kidney Disease", "Lunch Fats": 8
# "Ages": 32, "Gender": "Male", "Height": 190, "Weight": 90, "Activity Level": "Very Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 3000, "Protein": 180, "Sugar": 200.0, "Sodium": 36.0, "Calories": 3130, "Carbohydrates": 400, "Fiber": 48.0, "Fat": 90, "Breakfast Suggestion": "Oatmeal with protein powder and fruit", "Breakfast Calories": 365.0, "Breakfast Protein": 31.0, "Breakfast Carbohydrates": 83.0, "Breakfast Fats": 20.0, "Lunch Suggestion": "Chicken breast with sweet potato and broccoli", "Lunch Calories": 728.0, "Lunch Protein": 75.0, "Lunch Carbohydrates": 11.0, "Dinner Suggestion": "Steak with roasted vegetables", "Dinner Calories": 1156.0, "Dinner Protein.1": 115.0, "Dinner Carbohydrates.1": 115.0, "Dinner Fats": 52.0, "Snack Suggestion": "Protein shake", "Snacks Calories": 200, "Snacks Protein": 20, "Snacks Carbohydrates": 10, "Snacks Fats": 5, "Disease": "Weight Gain", "Lunch Fats": 12
# "Ages": 58, "Gender": "Male", "Height": 170, "Weight": 85, "Activity Level": "Moderately Active", "Dietary Preference": "Vegetarian", "Daily Calorie Target": 1900, "Protein": 100, "Sugar": 120.0, "Sodium": 20.0, "Calories": 1810, "Carbohydrates": 240, "Fiber": 28.8, "Fat": 50, "Breakfast Suggestion": "Eggs with whole wheat toast and avocado", "Breakfast Calories": 163.0, "Breakfast Protein": 20.0, "Breakfast Carbohydrates": 13.0, "Breakfast Fats": 8.0, "Lunch Suggestion": "Lentil soup with whole wheat bread", "Lunch Calories": 324.0, "Lunch Protein": 29.0, "Lunch Carbohydrates": 29.0, "Dinner Suggestion": "Vegetarian chili with brown rice", "Dinner Calories": 130.0, "Dinner Protein.1": 2.0, "Dinner Carbohydrates.1": 2.0, "Dinner Fats": 14.0, "Snack Suggestion": "Trail mix with nuts and dried fruit", "Snacks Calories": 350, "Snacks Protein": 10, "Snacks Carbohydrates": 40, "Snacks Fats": 25, "Disease": "Weight Gain", "Lunch Fats": 8
# "Ages": 22, "Gender": "Female", "Height": 160, "Weight": 50, "Activity Level": "Lightly Active", "Dietary Preference": "Vegan", "Daily Calorie Target": 1500, "Protein": 80, "Sugar": 100.0, "Sodium": 16.0, "Calories": 1480, "Carbohydrates": 200, "Fiber": 24.0, "Fat": 40, "Breakfast Suggestion": "Tofu scramble with vegetables", "Breakfast Calories": 190.0, "Breakfast Protein": 15.0, "Breakfast Carbohydrates": 23.0, "Breakfast Fats": 14.0, "Lunch Suggestion": "Vegan lentil stew with whole wheat bread", "Lunch Calories": 257.0, "Lunch Protein": 3.0, "Lunch Carbohydrates": 13.0, "Dinner Suggestion": "Tofu stir-fry with brown rice and vegetables", "Dinner Calories": 290.0, "Dinner Protein.1": 29.0, "Dinner Carbohydrates.1": 290.0, "Dinner Fats": 11.0, "Snack Suggestion": "Banana with almond butter", "Snacks Calories": 210, "Snacks Protein": 5, "Snacks Carbohydrates": 30, "Snacks Fats": 9, "Disease": "Weight Gain, Hypertension, Heart Disease", "Lunch Fats": 7
# "Ages": 25, "Gender": "Female", "Height": 165, "Weight": 60, "Activity Level": "Lightly Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 1800, "Protein": 80, "Sugar": 100.0, "Sodium": 16.0, "Calories": 1660, "Carbohydrates": 200, "Fiber": 24.0, "Fat": 60, "Breakfast Suggestion": "Greek yogurt with berries and granola", "Breakfast Calories": 468.0, "Breakfast Protein": 23.0, "Breakfast Carbohydrates": 47.0, "Breakfast Fats": 11.0, "Lunch Suggestion": "Lentil soup with whole wheat bread", "Lunch Calories": 432.0, "Lunch Protein": 7.2, "Lunch Carbohydrates": 47.0, "Dinner Suggestion": "Salmon with roasted vegetables", "Dinner Calories": 429.0, "Dinner Protein.1": 32.0, "Dinner Carbohydrates.1": 15.0, "Dinner Fats": 23.0, "Snack Suggestion": "Apple slices with peanut butter", "Snacks Calories": 180, "Snacks Protein": 4, "Snacks Carbohydrates": 30, "Snacks Fats": 8, "Disease": "Weight Gain", "Lunch Fats": 8
# "Ages": 38, "Gender": "Male", "Height": 180, "Weight": 85, "Activity Level": "Moderately Active", "Dietary Preference": "Vegetarian", "Daily Calorie Target": 2800, "Protein": 150, "Sugar": 125.0, "Sodium": 30.0, "Calories": 2320, "Carbohydrates": 250, "Fiber": 30.0, "Fat": 80, "Breakfast Suggestion": "Tofu scramble with spinach and avocado", "Breakfast Calories": 300.0, "Breakfast Protein": 18.0, "Breakfast Carbohydrates": 45.0, "Breakfast Fats": 13.0, "Lunch Suggestion": "Quinoa salad with chickpeas and vegetables", "Lunch Calories": 450.0, "Lunch Protein": 26.0, "Lunch Carbohydrates": 76.0, "Dinner Suggestion": "Black bean burgers with sweet potato fries", "Dinner Calories": 1021.0, "Dinner Protein.1": 87.0, "Dinner Carbohydrates.1": 254.0, "Dinner Fats": 82.0, "Snack Suggestion": "Mixed nuts and seeds", "Snacks Calories": 200, "Snacks Protein": 6, "Snacks Carbohydrates": 20, "Snacks Fats": 15, "Disease": "Weight Gain", "Lunch Fats": 9
# "Ages": 55, "Gender": "Female", "Height": 160, "Weight": 65, "Activity Level": "Sedentary", "Dietary Preference": "Vegan", "Daily Calorie Target": 1600, "Protein": 65, "Sugar": 90.0, "Sodium": 13.0, "Calories": 1430, "Carbohydrates": 180, "Fiber": 21.6, "Fat": 50, "Breakfast Suggestion": "Overnight oats with fruit and chia seeds", "Breakfast Calories": 339.0, "Breakfast Protein": 10.9, "Breakfast Carbohydrates": 33.3, "Breakfast Fats": 15.0, "Lunch Suggestion": "Lentil and vegetable curry with brown rice", "Lunch Calories": 638.0, "Lunch Protein": 37.9, "Lunch Carbohydrates": 37.9, "Dinner Suggestion": "Tofu stir-fry with brown rice noodles", "Dinner Calories": 663.0, "Dinner Protein.1": 2.5, "Dinner Carbohydrates.1": 43.3, "Dinner Fats": 19.3, "Snack Suggestion": "Fruit smoothie", "Snacks Calories": 150, "Snacks Protein": 2, "Snacks Carbohydrates": 35, "Snacks Fats": 1, "Disease": "Weight Gain, Kidney Disease", "Lunch Fats": 10
# "Ages": 42, "Gender": "Male", "Height": 190, "Weight": 95, "Activity Level": "Very Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 3200, "Protein": 200, "Sugar": 150.0, "Sodium": 40.0, "Calories": 2900, "Carbohydrates": 300, "Fiber": 36.0, "Fat": 100, "Breakfast Suggestion": "Scrambled eggs with whole wheat toast and fruit", "Breakfast Calories": 169.0, "Breakfast Protein": 27.0, "Breakfast Carbohydrates": 17.0, "Breakfast Fats": 6.0, "Lunch Suggestion": "Chicken breast with brown rice and vegetables", "Lunch Calories": 56.0, "Lunch Protein": 56.0, "Lunch Carbohydrates": 39.0, "Dinner Suggestion": "Steak with sweet potato and asparagus", "Dinner Calories": 409.0, "Dinner Protein.1": 11.0, "Dinner Carbohydrates.1": 30.0, "Dinner Fats": 10.0, "Snack Suggestion": "Protein shake", "Snacks Calories": 200, "Snacks Protein": 20, "Snacks Carbohydrates": 10, "Snacks Fats": 5, "Disease": "Weight Gain", "Lunch Fats": 11
# "Ages": 62, "Gender": "Female", "Height": 155, "Weight": 58, "Activity Level": "Sedentary", "Dietary Preference": "Vegan", "Daily Calorie Target": 1400, "Protein": 55, "Sugar": 75.0, "Sodium": 11.0, "Calories": 1180, "Carbohydrates": 150, "Fiber": 18.0, "Fat": 40, "Breakfast Suggestion": "Oatmeal with berries and plant-based milk", "Breakfast Calories": 380.0, "Breakfast Protein": 19.0, "Breakfast Carbohydrates": 42.0, "Breakfast Fats": 11.0, "Lunch Suggestion": "Lentil soup with whole wheat bread", "Lunch Calories": 420.0, "Lunch Protein": 29.0, "Lunch Carbohydrates": 68.0, "Dinner Suggestion": "Vegetable stir-fry with tofu and brown rice", "Dinner Calories": 780.0, "Dinner Protein.1": 61.0, "Dinner Carbohydrates.1": 15.0, "Dinner Fats": 22.0, "Snack Suggestion": "Apple slices with almond butter", "Snacks Calories": 180, "Snacks Protein": 6, "Snacks Carbohydrates": 30, "Snacks Fats": 8, "Disease": "Weight Gain, Hypertension, Heart Disease, Kidney Disease", "Lunch Fats": 8
# "Ages": 28, "Gender": "Male", "Height": 175, "Weight": 70, "Activity Level": "Moderately Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 2500, "Protein": 130, "Sugar": 110.0, "Sodium": 26.0, "Calories": 2030, "Carbohydrates": 220, "Fiber": 26.4, "Fat": 70, "Breakfast Suggestion": "Greek yogurt with fruit and granola", "Breakfast Calories": 560.0, "Breakfast Protein": 13.0, "Breakfast Carbohydrates": 38.0, "Breakfast Fats": 3.5, "Lunch Suggestion": "Tuna salad sandwich on whole wheat bread", "Lunch Calories": 840.0, "Lunch Protein": 57.0, "Lunch Carbohydrates": 52.0, "Dinner Suggestion": "Chicken breast with brown rice and vegetables", "Dinner Calories": 760.0, "Dinner Protein.1": 76.0, "Dinner Carbohydrates.1": 17.0, "Dinner Fats": 35.2, "Snack Suggestion": "Trail mix", "Snacks Calories": 300, "Snacks Protein": 8, "Snacks Carbohydrates": 34, "Snacks Fats": 20, "Disease": "Weight Gain", "Lunch Fats": 13
# "Ages": 31, "Gender": "Female", "Height": 170, "Weight": 75, "Activity Level": "Lightly Active", "Dietary Preference": "Vegetarian", "Daily Calorie Target": 1700, "Protein": 70, "Sugar": 95.0, "Sodium": 14.0, "Calories": 1490, "Carbohydrates": 190, "Fiber": 22.8, "Fat": 50, "Breakfast Suggestion": "Scrambled eggs with whole wheat toast and avocado", "Breakfast Calories": 333.0, "Breakfast Protein": 14.0, "Breakfast Carbohydrates": 45.0, "Breakfast Fats": 20.0, "Lunch Suggestion": "Vegetarian chili with whole wheat bread", "Lunch Calories": 462.0, "Lunch Protein": 43.0, "Lunch Carbohydrates": 43.0, "Dinner Suggestion": "Black bean burgers with salad", "Dinner Calories": 468.0, "Dinner Protein.1": 38.0, "Dinner Carbohydrates.1": 61.0, "Dinner Fats": 21.0, "Snack Suggestion": "Apple slices with almond butter", "Snacks Calories": 180, "Snacks Protein": 6, "Snacks Carbohydrates": 30, "Snacks Fats": 8, "Disease": "Weight Gain, Kidney Disease", "Lunch Fats": 8
# "Ages": 58, "Gender": "Male", "Height": 185, "Weight": 90, "Activity Level": "Moderately Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 2400, "Protein": 100, "Sugar": 120.0, "Sodium": 20.0, "Calories": 1990, "Carbohydrates": 240, "Fiber": 28.8, "Fat": 70, "Breakfast Suggestion": "Oatmeal with fruit and nuts", "Breakfast Calories": 199.0, "Breakfast Protein": 39.0, "Breakfast Carbohydrates": 19.0, "Breakfast Fats": 19.0, "Lunch Suggestion": "Chicken salad sandwich on whole wheat bread", "Lunch Calories": 470.0, "Lunch Protein": 42.0, "Lunch Carbohydrates": 55.0, "Dinner Suggestion": "Salmon with roasted vegetables", "Dinner Calories": 780.0, "Dinner Protein.1": 43.0, "Dinner Carbohydrates.1": 91.0, "Dinner Fats": 47.0, "Snack Suggestion": "Fruit and cheese", "Snacks Calories": 200, "Snacks Protein": 10, "Snacks Carbohydrates": 15, "Snacks Fats": 10, "Disease": "Weight Gain", "Lunch Fats": 11
# "Ages": 22, "Gender": "Female", "Height": 168, "Weight": 55, "Activity Level": "Very Active", "Dietary Preference": "Vegan", "Daily Calorie Target": 2200, "Protein": 110, "Sugar": 100.0, "Sodium": 22.0, "Calories": 1780, "Carbohydrates": 200, "Fiber": 24.0, "Fat": 60, "Breakfast Suggestion": "Overnight oats with fruit and chia seeds", "Breakfast Calories": 590.0, "Breakfast Protein": 13.0, "Breakfast Carbohydrates": 24.0, "Breakfast Fats": 16.0, "Lunch Suggestion": "Tofu scramble with spinach and avocado", "Lunch Calories": 611.0, "Lunch Protein": 32.0, "Lunch Carbohydrates": 10.0, "Dinner Suggestion": "Lentil and vegetable curry with brown rice", "Dinner Calories": 395.0, "Dinner Protein.1": 30.0, "Dinner Carbohydrates.1": 70.0, "Dinner Fats": 16.0, "Snack Suggestion": "Protein shake", "Snacks Calories": 200, "Snacks Protein": 20, "Snacks Carbohydrates": 10, "Snacks Fats": 5, "Disease": "Weight Gain", "Lunch Fats": 14
# "Ages": 45, "Gender": "Male", "Height": 182, "Weight": 80, "Activity Level": "Lightly Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 2000, "Protein": 90, "Sugar": 110.0, "Sodium": 18.0, "Calories": 1780, "Carbohydrates": 220, "Fiber": 26.4, "Fat": 60, "Breakfast Suggestion": "Greek yogurt with fruit and granola", "Breakfast Calories": 210.0, "Breakfast Protein": 27.0, "Breakfast Carbohydrates": 52.0, "Breakfast Fats": 26.0, "Lunch Suggestion": "Chicken breast salad with vegetables", "Lunch Calories": 328.0, "Lunch Protein": 32.0, "Lunch Carbohydrates": 31.0, "Dinner Suggestion": "Turkey chili with brown rice", "Dinner Calories": 423.0, "Dinner Protein.1": 43.0, "Dinner Carbohydrates.1": 14.0, "Dinner Fats": 30.0, "Snack Suggestion": "Fruit and yogurt", "Snacks Calories": 150, "Snacks Protein": 10, "Snacks Carbohydrates": 20, "Snacks Fats": 5, "Disease": "Weight Gain", "Lunch Fats": 10
# "Ages": 25, "Gender": "Male", "Height": 180, "Weight": 80, "Activity Level": "Moderately Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 2200, "Protein": 120, "Sugar": 125.0, "Sodium": 24.0, "Calories": 2020, "Carbohydrates": 250, "Fiber": 30.0, "Fat": 60, "Breakfast Suggestion": "Oatmeal with berries and nuts", "Breakfast Calories": 370.0, "Breakfast Protein": 31.0, "Breakfast Carbohydrates": 47.0, "Breakfast Fats": 19.0, "Lunch Suggestion": "Grilled chicken salad with mixed greens", "Lunch Calories": 450.0, "Lunch Protein": 45.0, "Lunch Carbohydrates": 15.0, "Dinner Suggestion": "Salmon with roasted vegetables", "Dinner Calories": 557.0, "Dinner Protein.1": 46.0, "Dinner Carbohydrates.1": 44.0, "Dinner Fats": 44.0, "Snack Suggestion": "Greek yogurt with fruit", "Snacks Calories": 150, "Snacks Protein": 10, "Snacks Carbohydrates": 20, "Snacks Fats": 5, "Disease": "Weight Gain", "Lunch Fats": 12
# "Ages": 32, "Gender": "Female", "Height": 165, "Weight": 65, "Activity Level": "Lightly Active", "Dietary Preference": "Vegetarian", "Daily Calorie Target": 2000, "Protein": 100, "Sugar": 100.0, "Sodium": 20.0, "Calories": 1740, "Carbohydrates": 200, "Fiber": 24.0, "Fat": 60, "Breakfast Suggestion": "Tofu scramble with whole-wheat toast", "Breakfast Calories": 1740.0, "Breakfast Protein": 14.0, "Breakfast Carbohydrates": 24.0, "Breakfast Fats": 18.0, "Lunch Suggestion": "Lentil soup with whole-wheat bread", "Lunch Calories": 700.0, "Lunch Protein": 13.0, "Lunch Carbohydrates": 24.0, "Dinner Suggestion": "Vegetable stir-fry with brown rice", "Dinner Calories": 900.0, "Dinner Protein.1": 28.0, "Dinner Carbohydrates.1": 195.0, "Dinner Fats": 60.0, "Snack Suggestion": "Trail mix with nuts and dried fruit", "Snacks Calories": 350, "Snacks Protein": 10, "Snacks Carbohydrates": 40, "Snacks Fats": 25, "Disease": "Weight Gain", "Lunch Fats": 8
# "Ages": 55, "Gender": "Male", "Height": 175, "Weight": 90, "Activity Level": "Sedentary", "Dietary Preference": "Vegan", "Daily Calorie Target": 2000, "Protein": 80, "Sugar": 125.0, "Sodium": 16.0, "Calories": 1770, "Carbohydrates": 250, "Fiber": 30.0, "Fat": 50, "Breakfast Suggestion": "Tofu and vegetable breakfast burrito", "Breakfast Calories": 260.0, "Breakfast Protein": 15.0, "Breakfast Carbohydrates": 34.0, "Breakfast Fats": 3.0, "Lunch Suggestion": "Black bean burger on a whole-wheat bun", "Lunch Calories": 560.0, "Lunch Protein": 37.0, "Lunch Carbohydrates": 48.0, "Dinner Suggestion": "Lentil pasta with marinara sauce", "Dinner Calories": 206.0, "Dinner Protein.1": 25.0, "Dinner Carbohydrates.1": 206.0, "Dinner Fats": 16.0, "Snack Suggestion": "Fruit salad with nuts", "Snacks Calories": 150, "Snacks Protein": 4, "Snacks Carbohydrates": 25, "Snacks Fats": 7, "Disease": "Weight Gain", "Lunch Fats": 15
# "Ages": 68, "Gender": "Female", "Height": 160, "Weight": 75, "Activity Level": "Lightly Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 1800, "Protein": 80, "Sugar": 90.0, "Sodium": 16.0, "Calories": 1490, "Carbohydrates": 180, "Fiber": 21.6, "Fat": 50, "Breakfast Suggestion": "Greek yogurt with granola", "Breakfast Calories": 222.0, "Breakfast Protein": 20.9, "Breakfast Carbohydrates": 49.0, "Breakfast Fats": 30.0, "Lunch Suggestion": "Chicken breast salad with mixed greens", "Lunch Calories": 421.0, "Lunch Protein": 28.0, "Lunch Carbohydrates": 17.0, "Dinner Suggestion": "Turkey meatballs with steamed vegetables", "Dinner Calories": 480.0, "Dinner Protein.1": 47.0, "Dinner Carbohydrates.1": 18.0, "Dinner Fats": 20.0, "Snack Suggestion": "Popcorn", "Snacks Calories": 100, "Snacks Protein": 3, "Snacks Carbohydrates": 15, "Snacks Fats": 5, "Disease": "Weight Gain", "Lunch Fats": 10
# "Ages": 28, "Gender": "Male", "Height": 185, "Weight": 95, "Activity Level": "Very Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 3000, "Protein": 160, "Sugar": 175.0, "Sodium": 32.0, "Calories": 2760, "Carbohydrates": 350, "Fiber": 42.0, "Fat": 80, "Breakfast Suggestion": "Scrambled eggs with avocado and whole-wheat toast", "Breakfast Calories": 423.0, "Breakfast Protein": 29.0, "Breakfast Carbohydrates": 24.0, "Breakfast Fats": 26.0, "Lunch Suggestion": "Chicken breast with brown rice and vegetables", "Lunch Calories": 659.0, "Lunch Protein": 25.0, "Lunch Carbohydrates": 131.0, "Dinner Suggestion": "Steak with sweet potato fries", "Dinner Calories": 741.0, "Dinner Protein.1": 80.0, "Dinner Carbohydrates.1": 38.0, "Dinner Fats": 42.0, "Snack Suggestion": "Protein shake with banana", "Snacks Calories": 200, "Snacks Protein": 20, "Snacks Carbohydrates": 30, "Snacks Fats": 2, "Disease": "Weight Gain", "Lunch Fats": 11
# "Ages": 38, "Gender": "Female", "Height": 170, "Weight": 70, "Activity Level": "Moderately Active", "Dietary Preference": "Vegan", "Daily Calorie Target": 1800, "Protein": 80, "Sugar": 100.0, "Sodium": 16.0, "Calories": 1570, "Carbohydrates": 200, "Fiber": 24.0, "Fat": 50, "Breakfast Suggestion": "Overnight oats with chia seeds and fruit", "Breakfast Calories": 260.0, "Breakfast Protein": 7.0, "Breakfast Carbohydrates": 25.0, "Breakfast Fats": 10.0, "Lunch Suggestion": "Tofu and vegetable stir-fry with brown rice", "Lunch Calories": 454.0, "Lunch Protein": 6.0, "Lunch Carbohydrates": 8.0, "Dinner Suggestion": "Lentil soup with whole-wheat bread", "Dinner Calories": 1160.0, "Dinner Protein.1": 41.0, "Dinner Carbohydrates.1": 140.0, "Dinner Fats": 28.0, "Snack Suggestion": "Fruit salad with nuts", "Snacks Calories": 150, "Snacks Protein": 4, "Snacks Carbohydrates": 25, "Snacks Fats": 7, "Disease": "Weight Gain", "Lunch Fats": 12
# "Ages": 62, "Gender": "Male", "Height": 170, "Weight": 85, "Activity Level": "Sedentary", "Dietary Preference": "Omnivore", "Daily Calorie Target": 2200, "Protein": 80, "Sugar": 135.0, "Sodium": 16.0, "Calories": 1940, "Carbohydrates": 270, "Fiber": 32.4, "Fat": 60, "Breakfast Suggestion": "Pancakes with fruit and syrup", "Breakfast Calories": 220.0, "Breakfast Protein": 13.9, "Breakfast Carbohydrates": 20.0, "Breakfast Fats": 5.0, "Lunch Suggestion": "Grilled chicken sandwich with whole-wheat bread", "Lunch Calories": 300.0, "Lunch Protein": 19.0, "Lunch Carbohydrates": 272.0, "Dinner Suggestion": "Chicken stir-fry with brown rice", "Dinner Calories": 1940.0, "Dinner Protein.1": 53.0, "Dinner Carbohydrates.1": 270.0, "Dinner Fats": 60.0, "Snack Suggestion": "Popcorn", "Snacks Calories": 100, "Snacks Protein": 3, "Snacks Carbohydrates": 15, "Snacks Fats": 5, "Disease": "Weight Gain", "Lunch Fats": 13
# "Ages": 45, "Gender": "Female", "Height": 168, "Weight": 60, "Activity Level": "Very Active", "Dietary Preference": "Vegetarian", "Daily Calorie Target": 2400, "Protein": 120, "Sugar": 140.0, "Sodium": 24.0, "Calories": 2230, "Carbohydrates": 280, "Fiber": 33.6, "Fat": 70, "Breakfast Suggestion": "Tofu scramble with whole-wheat toast", "Breakfast Calories": 304.0, "Breakfast Protein": 20.0, "Breakfast Carbohydrates": 18.0, "Breakfast Fats": 17.0, "Lunch Suggestion": "Black bean burger on a whole-wheat bun", "Lunch Calories": 490.0, "Lunch Protein": 35.0, "Lunch Carbohydrates": 39.0, "Dinner Suggestion": "Chickpea curry with brown rice", "Dinner Calories": 440.0, "Dinner Protein.1": 27.0, "Dinner Carbohydrates.1": 44.0, "Dinner Fats": 5.0, "Snack Suggestion": "Energy bar with nuts and seeds", "Snacks Calories": 250, "Snacks Protein": 8, "Snacks Carbohydrates": 30, "Snacks Fats": 12, "Disease": "Weight Gain", "Lunch Fats": 15
# "Ages": 22, "Gender": "Female", "Height": 172, "Weight": 55, "Activity Level": "Moderately Active", "Dietary Preference": "Vegan", "Daily Calorie Target": 1800, "Protein": 80, "Sugar": 100.0, "Sodium": 16.0, "Calories": 1570, "Carbohydrates": 200, "Fiber": 24.0, "Fat": 50, "Breakfast Suggestion": "Overnight oats with chia seeds and fruit", "Breakfast Calories": 385.9, "Breakfast Protein": 22.0, "Breakfast Carbohydrates": 61.0, "Breakfast Fats": 30.0, "Lunch Suggestion": "Tofu and vegetable stir-fry with brown rice", "Lunch Calories": 764.3, "Lunch Protein": 5.0, "Lunch Carbohydrates": 11.0, "Dinner Suggestion": "Lentil stew with whole-wheat bread", "Dinner Calories": 784.0, "Dinner Protein.1": 58.0, "Dinner Carbohydrates.1": 104.0, "Dinner Fats": 50.0, "Snack Suggestion": "Trail mix with nuts and dried fruit", "Snacks Calories": 350, "Snacks Protein": 10, "Snacks Carbohydrates": 40, "Snacks Fats": 25, "Disease": "Weight Gain", "Lunch Fats": 12
# "Ages": 58, "Gender": "Male", "Height": 178, "Weight": 98, "Activity Level": "Sedentary", "Dietary Preference": "Omnivore", "Daily Calorie Target": 2000, "Protein": 80, "Sugar": 125.0, "Sodium": 16.0, "Calories": 1770, "Carbohydrates": 250, "Fiber": 30.0, "Fat": 50, "Breakfast Suggestion": "Scrambled eggs with whole-wheat toast", "Breakfast Calories": 465.0, "Breakfast Protein": 35.0, "Breakfast Carbohydrates": 55.0, "Breakfast Fats": 19.0, "Lunch Suggestion": "Tuna salad sandwich with whole-wheat bread", "Lunch Calories": 670.0, "Lunch Protein": 43.0, "Lunch Carbohydrates": 78.0, "Dinner Suggestion": "Chicken breast with roasted vegetables", "Dinner Calories": 422.0, "Dinner Protein.1": 42.0, "Dinner Carbohydrates.1": 42.0, "Dinner Fats": 10.0, "Snack Suggestion": "Fruit salad with nuts", "Snacks Calories": 150, "Snacks Protein": 4, "Snacks Carbohydrates": 25, "Snacks Fats": 7, "Disease": "Weight Gain", "Lunch Fats": 13
# "Ages": 25, "Gender": "Male", "Height": 180, "Weight": 85, "Activity Level": "Lightly Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 2000, "Protein": 120, "Sugar": 125.0, "Sodium": 24.0, "Calories": 2065, "Carbohydrates": 250, "Fiber": 30.0, "Fat": 65, "Breakfast Suggestion": "Greek yogurt with berries and granola", "Breakfast Calories": 245.0, "Breakfast Protein": 31.0, "Breakfast Carbohydrates": 47.0, "Breakfast Fats": 29.0, "Lunch Suggestion": "Chicken breast salad with mixed greens", "Lunch Calories": 240.0, "Lunch Protein": 24.0, "Lunch Carbohydrates": 240.0, "Dinner Suggestion": "Salmon with roasted vegetables", "Dinner Calories": 420.0, "Dinner Protein.1": 33.0, "Dinner Carbohydrates.1": 30.0, "Dinner Fats": 29.0, "Snack Suggestion": "Apple with peanut butter", "Snacks Calories": 180, "Snacks Protein": 4, "Snacks Carbohydrates": 30, "Snacks Fats": 8, "Disease": "Weight Gain", "Lunch Fats": 10
# ...
# "Ages": 28, "Gender": "Male", "Height": 156, "Weight": 69, "Activity Level": "Lightly Active", "Dietary Preference": "Vegetarian", "Daily Calorie Target": 2603, "Protein": 195, "Sugar": 130.0, "Sodium": 39.0, "Calories": 2594, "Carbohydrates": 260, "Fiber": 31.2, "Fat": 86, "Breakfast Suggestion": "Tofu scramble with veggies", "Breakfast Calories": 253.0, "Breakfast Protein": 29.0, "Breakfast Carbohydrates": 21.6, "Breakfast Fats": 15.7, "Lunch Suggestion": "Lentil soup with whole wheat bread", "Lunch Calories": 250.0, "Lunch Protein": 29.0, "Lunch Carbohydrates": 28.0, "Dinner Suggestion": "Turkey chili with brown rice", "Dinner Calories": 630.0, "Dinner Protein.1": 65.0, "Dinner Carbohydrates.1": 91.0, "Dinner Fats": 15.0, "Snack Suggestion": "Greek yogurt with fruit", "Snacks Calories": 150, "Snacks Protein": 10, "Snacks Carbohydrates": 20, "Snacks Fats": 5, "Disease": "Weight Gain", "Lunch Fats": 8
# "Ages": 50, "Gender": "Female", "Height": 186, "Weight": 92, "Activity Level": "Very Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 3383, "Protein": 253, "Sugar": 169.0, "Sodium": 50.6, "Calories": 3372, "Carbohydrates": 338, "Fiber": 40.56, "Fat": 112, "Breakfast Suggestion": "Tofu scramble with veggies", "Breakfast Calories": 137.0, "Breakfast Protein": 32.5, "Breakfast Carbohydrates": 15.9, "Breakfast Fats": 12.8, "Lunch Suggestion": "Black bean burger on a whole wheat bun", "Lunch Calories": 512.0, "Lunch Protein": 50.8, "Lunch Carbohydrates": 62.0, "Dinner Suggestion": "Pasta with marinara sauce and veggies", "Dinner Calories": 1123.0, "Dinner Protein.1": 112.0, "Dinner Carbohydrates.1": 112.0, "Dinner Fats": 12.8, "Snack Suggestion": "Fruit and nut mix", "Snacks Calories": 250, "Snacks Protein": 6, "Snacks Carbohydrates": 28, "Snacks Fats": 15, "Disease": "Weight Gain", "Lunch Fats": 15
# "Ages": 22, "Gender": "Female", "Height": 167, "Weight": 91, "Activity Level": "Extremely Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 3197, "Protein": 239, "Sugar": 159.5, "Sodium": 47.8, "Calories": 3186, "Carbohydrates": 319, "Fiber": 38.28, "Fat": 106, "Breakfast Suggestion": "Tofu scramble with veggies", "Breakfast Calories": 246.0, "Breakfast Protein": 21.4, "Breakfast Carbohydrates": 22.9, "Breakfast Fats": 9.4, "Lunch Suggestion": "Quinoa salad with chickpeas and vegetables", "Lunch Calories": 178.0, "Lunch Protein": 12.9, "Lunch Carbohydrates": 7.1, "Dinner Suggestion": "Turkey chili with brown rice", "Dinner Calories": 258.0, "Dinner Protein.1": 42.25, "Dinner Carbohydrates.1": 106.0, "Dinner Fats": 27.3, "Snack Suggestion": "Apple with almond butter", "Snacks Calories": 180, "Snacks Protein": 4, "Snacks Carbohydrates": 30, "Snacks Fats": 8, "Disease": "Weight Gain", "Lunch Fats": 9
# "Ages": 30, "Gender": "Female", "Height": 193, "Weight": 96, "Activity Level": "Sedentary", "Dietary Preference": "Vegan", "Daily Calorie Target": 2726, "Protein": 204, "Sugar": 136.0, "Sodium": 40.8, "Calories": 2714, "Carbohydrates": 272, "Fiber": 32.64, "Fat": 90, "Breakfast Suggestion": "Greek yogurt with granola and fruit", "Breakfast Calories": 369.0, "Breakfast Protein": 39.96666667, "Breakfast Carbohydrates": 52.0, "Breakfast Fats": 17.0, "Lunch Suggestion": "Grilled chicken salad with mixed greens", "Lunch Calories": 483.0, "Lunch Protein": 40.78, "Lunch Carbohydrates": 11.0, "Dinner Suggestion": "Lentil and vegetable curry", "Dinner Calories": 310.0, "Dinner Protein.1": 3.1, "Dinner Carbohydrates.1": 26.9, "Dinner Fats": 1.8, "Snack Suggestion": "Apple with almond butter", "Snacks Calories": 180, "Snacks Protein": 4, "Snacks Carbohydrates": 30, "Snacks Fats": 8, "Disease": "Weight Gain", "Lunch Fats": 12
# "Ages": 32, "Gender": "Female", "Height": 169, "Weight": 73, "Activity Level": "Sedentary", "Dietary Preference": "Vegan", "Daily Calorie Target": 1258, "Protein": 94, "Sugar": 62.5, "Sodium": 18.8, "Calories": 1245, "Carbohydrates": 125, "Fiber": 15.0, "Fat": 41, "Breakfast Suggestion": "Smoothie with protein powder", "Breakfast Calories": 300.0, "Breakfast Protein": 32.0, "Breakfast Carbohydrates": 20.9, "Breakfast Fats": 19.0, "Lunch Suggestion": "Chicken and vegetable stir-fry", "Lunch Calories": 488.0, "Lunch Protein": 56.0, "Lunch Carbohydrates": 128.0, "Dinner Suggestion": "Vegetable stir-fry with brown rice", "Dinner Calories": 42.0, "Dinner Protein.1": 28.0, "Dinner Carbohydrates.1": 12.0, "Dinner Fats": 19.0, "Snack Suggestion": "Banana with peanut butter", "Snacks Calories": 210, "Snacks Protein": 5, "Snacks Carbohydrates": 30, "Snacks Fats": 9, "Disease": "Diabetes, Acne, Weight Gain, Hypertension, Heart Disease", "Lunch Fats": 10
# "Ages": 67, "Gender": "Female", "Height": 193, "Weight": 52, "Activity Level": "Lightly Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 1200, "Protein": 90, "Sugar": 60.0, "Sodium": 18.0, "Calories": 1200, "Carbohydrates": 120, "Fiber": 14.4, "Fat": 40, "Breakfast Suggestion": "Scrambled eggs with whole wheat toast", "Breakfast Calories": 306.0, "Breakfast Protein": 19.0, "Breakfast Carbohydrates": 58.0, "Breakfast Fats": 15.0, "Lunch Suggestion": "Black bean burger on a whole wheat bun", "Lunch Calories": 450.0, "Lunch Protein": 23.0, "Lunch Carbohydrates": 63.0, "Dinner Suggestion": "Lentil and vegetable curry", "Dinner Calories": 607.0, "Dinner Protein.1": 50.0, "Dinner Carbohydrates.1": 30.0, "Dinner Fats": 20.0, "Snack Suggestion": "Fruit and nut mix", "Snacks Calories": 250, "Snacks Protein": 6, "Snacks Carbohydrates": 28, "Snacks Fats": 15, "Disease": "Diabetes, Acne, Hypertension, Heart Disease", "Lunch Fats": 15
# "Ages": 51, "Gender": "Female", "Height": 195, "Weight": 96, "Activity Level": "Extremely Active", "Dietary Preference": "Vegetarian", "Daily Calorie Target": 2849, "Protein": 213, "Sugar": 142.0, "Sodium": 42.6, "Calories": 2834, "Carbohydrates": 284, "Fiber": 34.08, "Fat": 94, "Breakfast Suggestion": "Tofu scramble with veggies", "Breakfast Calories": 234.0, "Breakfast Protein": 12.7, "Breakfast Carbohydrates": 29.27, "Breakfast Fats": 6.4, "Lunch Suggestion": "Quinoa salad with chickpeas and vegetables", "Lunch Calories": 569.0, "Lunch Protein": 5.0, "Lunch Carbohydrates": 69.99, "Dinner Suggestion": "Vegetable stir-fry with brown rice", "Dinner Calories": 660.0, "Dinner Protein.1": 33.0, "Dinner Carbohydrates.1": 94.0, "Dinner Fats": 38.0, "Snack Suggestion": "Apple with almond butter", "Snacks Calories": 180, "Snacks Protein": 4, "Snacks Carbohydrates": 30, "Snacks Fats": 8, "Disease": "Weight Gain", "Lunch Fats": 9
# "Ages": 43, "Gender": "Male", "Height": 175, "Weight": 82, "Activity Level": "Lightly Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 1842, "Protein": 138, "Sugar": 92.0, "Sodium": 27.6, "Calories": 1837, "Carbohydrates": 184, "Fiber": 22.08, "Fat": 61, "Breakfast Suggestion": "Oatmeal with berries and nuts", "Breakfast Calories": 356.0, "Breakfast Protein": 24.0, "Breakfast Carbohydrates": 34.0, "Breakfast Fats": 2.0, "Lunch Suggestion": "Chicken and vegetable stir-fry", "Lunch Calories": 508.0, "Lunch Protein": 49.0, "Lunch Carbohydrates": 68.5, "Dinner Suggestion": "Pasta with marinara sauce and veggies", "Dinner Calories": 917.0, "Dinner Protein.1": 68.0, "Dinner Carbohydrates.1": 160.6, "Dinner Fats": 83.0, "Snack Suggestion": "Greek yogurt with fruit", "Snacks Calories": 150, "Snacks Protein": 10, "Snacks Carbohydrates": 20, "Snacks Fats": 5, "Disease": "Weight Gain", "Lunch Fats": 10
# "Ages": 67, "Gender": "Male", "Height": 179, "Weight": 69, "Activity Level": "Very Active", "Dietary Preference": "Vegetarian", "Daily Calorie Target": 2550, "Protein": 191, "Sugar": 127.5, "Sodium": 38.2, "Calories": 2549, "Carbohydrates": 255, "Fiber": 30.6, "Fat": 85, "Breakfast Suggestion": "Oatmeal with berries and nuts", "Breakfast Calories": 378.6, "Breakfast Protein": 14.6, "Breakfast Carbohydrates": 56.6, "Breakfast Fats": 29.9, "Lunch Suggestion": "Lentil soup with whole wheat bread", "Lunch Calories": 500.0, "Lunch Protein": 29.1, "Lunch Carbohydrates": 162.8, "Dinner Suggestion": "Lentil and vegetable curry", "Dinner Calories": 549.0, "Dinner Protein.1": 29.1, "Dinner Carbohydrates.1": 29.1, "Dinner Fats": 85.4, "Snack Suggestion": "Banana with peanut butter", "Snacks Calories": 210, "Snacks Protein": 5, "Snacks Carbohydrates": 30, "Snacks Fats": 9, "Disease": "Weight Gain", "Lunch Fats": 8
# "Ages": 25, "Gender": "Male", "Height": 170, "Weight": 88, "Activity Level": "Sedentary", "Dietary Preference": "Vegetarian", "Daily Calorie Target": 1687, "Protein": 126, "Sugar": 84.0, "Sodium": 25.2, "Calories": 1680, "Carbohydrates": 168, "Fiber": 20.16, "Fat": 56, "Breakfast Suggestion": "Scrambled eggs with whole wheat toast", "Breakfast Calories": 168.0, "Breakfast Protein": 20.5, "Breakfast Carbohydrates": 52.0, "Breakfast Fats": 5.7, "Lunch Suggestion": "Quinoa salad with chickpeas and vegetables", "Lunch Calories": 168.0, "Lunch Protein": 20.0, "Lunch Carbohydrates": 168.0, "Dinner Suggestion": "Pasta with marinara sauce and veggies", "Dinner Calories": 550.0, "Dinner Protein.1": 26.7, "Dinner Carbohydrates.1": 168.0, "Dinner Fats": 20.0, "Snack Suggestion": "Trail mix", "Snacks Calories": 300, "Snacks Protein": 8, "Snacks Carbohydrates": 34, "Snacks Fats": 20, "Disease": "Weight Gain", "Lunch Fats": 9
# "Ages": 21, "Gender": "Female", "Height": 180, "Weight": 99, "Activity Level": "Extremely Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 3513, "Protein": 263, "Sugar": 175.5, "Sodium": 52.6, "Calories": 3509, "Carbohydrates": 351, "Fiber": 42.12, "Fat": 117, "Breakfast Suggestion": "Scrambled eggs with whole wheat toast", "Breakfast Calories": 273.5, "Breakfast Protein": 26.3, "Breakfast Carbohydrates": 71.0, "Breakfast Fats": 29.0, "Lunch Suggestion": "Chicken and vegetable stir-fry", "Lunch Calories": 602.0, "Lunch Protein": 4.3, "Lunch Carbohydrates": 25.1, "Dinner Suggestion": "Lentil and vegetable curry", "Dinner Calories": 645.0, "Dinner Protein.1": 5.99, "Dinner Carbohydrates.1": 81.67, "Dinner Fats": 2.5, "Snack Suggestion": "Greek yogurt with fruit", "Snacks Calories": 150, "Snacks Protein": 10, "Snacks Carbohydrates": 20, "Snacks Fats": 5, "Disease": "Weight Gain", "Lunch Fats": 10
# "Ages": 50, "Gender": "Male", "Height": 176, "Weight": 62, "Activity Level": "Sedentary", "Dietary Preference": "Vegan", "Daily Calorie Target": 1770, "Protein": 132, "Sugar": 88.5, "Sodium": 26.4, "Calories": 1767, "Carbohydrates": 177, "Fiber": 21.24, "Fat": 59, "Breakfast Suggestion": "Tofu scramble with veggies", "Breakfast Calories": 25.0, "Breakfast Protein": 4.1, "Breakfast Carbohydrates": 12.0, "Breakfast Fats": 1.2, "Lunch Suggestion": "Black bean burger on a whole wheat bun", "Lunch Calories": 1767.0, "Lunch Protein": 20.0, "Lunch Carbohydrates": 177.0, "Dinner Suggestion": "Vegetable stir-fry with brown rice", "Dinner Calories": 177.0, "Dinner Protein.1": 21.84, "Dinner Carbohydrates.1": 177.0, "Dinner Fats": 59.0, "Snack Suggestion": "Fruit and nut mix", "Snacks Calories": 250, "Snacks Protein": 6, "Snacks Carbohydrates": 28, "Snacks Fats": 15, "Disease": "Weight Gain", "Lunch Fats": 15
# "Ages": 53, "Gender": "Female", "Height": 182, "Weight": 76, "Activity Level": "Sedentary", "Dietary Preference": "Vegan", "Daily Calorie Target": 1265, "Protein": 94, "Sugar": 63.0, "Sodium": 18.8, "Calories": 1258, "Carbohydrates": 126, "Fiber": 15.12, "Fat": 42, "Breakfast Suggestion": "Oatmeal with berries and nuts", "Breakfast Calories": 396.0, "Breakfast Protein": 24.0, "Breakfast Carbohydrates": 36.0, "Breakfast Fats": 17.0, "Lunch Suggestion": "Quinoa salad with chickpeas and vegetables", "Lunch Calories": 492.0, "Lunch Protein": 12.0, "Lunch Carbohydrates": 56.0, "Dinner Suggestion": "Vegetable stir-fry with brown rice", "Dinner Calories": 687.0, "Dinner Protein.1": 42.0, "Dinner Carbohydrates.1": 126.0, "Dinner Fats": 25.0, "Snack Suggestion": "Apple with almond butter", "Snacks Calories": 180, "Snacks Protein": 4, "Snacks Carbohydrates": 30, "Snacks Fats": 8, "Disease": "Diabetes, Acne, Weight Gain, Hypertension, Heart Disease", "Lunch Fats": 9
# "Ages": 38, "Gender": "Male", "Height": 150, "Weight": 76, "Activity Level": "Very Active", "Dietary Preference": "Vegan", "Daily Calorie Target": 2109, "Protein": 158, "Sugar": 105.0, "Sodium": 31.6, "Calories": 2102, "Carbohydrates": 210, "Fiber": 25.2, "Fat": 70, "Breakfast Suggestion": "Oatmeal with berries and nuts", "Breakfast Calories": 325.0, "Breakfast Protein": 12.0, "Breakfast Carbohydrates": 51.0, "Breakfast Fats": 18.0, "Lunch Suggestion": "Grilled chicken salad with mixed greens", "Lunch Calories": 260.0, "Lunch Protein": 12.0, "Lunch Carbohydrates": 11.0, "Dinner Suggestion": "Lentil and vegetable curry", "Dinner Calories": 570.0, "Dinner Protein.1": 43.0, "Dinner Carbohydrates.1": 58.0, "Dinner Fats": 13.0, "Snack Suggestion": "Apple with almond butter", "Snacks Calories": 180, "Snacks Protein": 4, "Snacks Carbohydrates": 30, "Snacks Fats": 8, "Disease": "Weight Gain", "Lunch Fats": 12
# "Ages": 57, "Gender": "Male", "Height": 165, "Weight": 73, "Activity Level": "Very Active", "Dietary Preference": "Vegan", "Daily Calorie Target": 2555, "Protein": 191, "Sugar": 127.5, "Sodium": 38.2, "Calories": 2549, "Carbohydrates": 255, "Fiber": 30.6, "Fat": 85, "Breakfast Suggestion": "Smoothie with protein powder", "Breakfast Calories": 89.0, "Breakfast Protein": 13.8, "Breakfast Carbohydrates": 12.2, "Breakfast Fats": 23.0, "Lunch Suggestion": "Chicken and vegetable stir-fry", "Lunch Calories": 500.0, "Lunch Protein": 10.9, "Lunch Carbohydrates": 26.2, "Dinner Suggestion": "Vegetable stir-fry with brown rice", "Dinner Calories": 521.0, "Dinner Protein.1": 60.0, "Dinner Carbohydrates.1": 54.0, "Dinner Fats": 23.0, "Snack Suggestion": "Fruit and nut mix", "Snacks Calories": 250, "Snacks Protein": 6, "Snacks Carbohydrates": 28, "Snacks Fats": 15, "Disease": "Weight Gain", "Lunch Fats": 10
# "Ages": 40, "Gender": "Male", "Height": 166, "Weight": 91, "Activity Level": "Extremely Active", "Dietary Preference": "Vegan", "Daily Calorie Target": 3329, "Protein": 249, "Sugar": 166.0, "Sodium": 49.8, "Calories": 3314, "Carbohydrates": 332, "Fiber": 39.84, "Fat": 110, "Breakfast Suggestion": "Scrambled eggs with whole wheat toast", "Breakfast Calories": 70.0, "Breakfast Protein": 30.0, "Breakfast Carbohydrates": 8.0, "Breakfast Fats": 17.0, "Lunch Suggestion": "Lentil soup with whole wheat bread", "Lunch Calories": 900.0, "Lunch Protein": 36.0, "Lunch Carbohydrates": 112.0, "Dinner Suggestion": "Vegetable stir-fry with brown rice", "Dinner Calories": 80.0, "Dinner Protein.1": 28.0, "Dinner Carbohydrates.1": 42.0, "Dinner Fats": 26.0, "Snack Suggestion": "Banana with peanut butter", "Snacks Calories": 210, "Snacks Protein": 5, "Snacks Carbohydrates": 30, "Snacks Fats": 9, "Disease": "Weight Gain", "Lunch Fats": 8
# "Ages": 54, "Gender": "Female", "Height": 198, "Weight": 75, "Activity Level": "Sedentary", "Dietary Preference": "Vegetarian", "Daily Calorie Target": 1867, "Protein": 140, "Sugar": 93.0, "Sodium": 28.0, "Calories": 1862, "Carbohydrates": 186, "Fiber": 22.32, "Fat": 62, "Breakfast Suggestion": "Scrambled eggs with whole wheat toast", "Breakfast Calories": 219.0, "Breakfast Protein": 14.0, "Breakfast Carbohydrates": null, "Breakfast Fats": 20.0, "Lunch Suggestion": "Chicken and vegetable stir-fry", "Lunch Calories": 685.0, "Lunch Protein": 26.0, "Lunch Carbohydrates": 43.0, "Dinner Suggestion": "Pasta with marinara sauce and veggies", "Dinner Calories": 388.0, "Dinner Protein.1": 24.0, "Dinner Carbohydrates.1": 32.6, "Dinner Fats": 21.6, "Snack Suggestion": "Banana with peanut butter", "Snacks Calories": 210, "Snacks Protein": 5, "Snacks Carbohydrates": 30, "Snacks Fats": 9, "Disease": "Weight Gain", "Lunch Fats": 10

# %%
df = pd.DataFrame.from_dict(text_data, orient='index')

# %%
df.columns = ['Text']
df
# Out:
#                                                    Text
# 1     "Ages": 25, "Gender": "Male", "Height": 180, "...
# 2     "Ages": 32, "Gender": "Female", "Height": 165,...
# 3     "Ages": 48, "Gender": "Male", "Height": 175, "...
# 4     "Ages": 55, "Gender": "Female", "Height": 160,...
# 5     "Ages": 62, "Gender": "Male", "Height": 170, "...
# ...                                                 ...
# 1694  "Ages": 53, "Gender": "Female", "Height": 182,...
# 1695  "Ages": 38, "Gender": "Male", "Height": 150, "...
# 1696  "Ages": 57, "Gender": "Male", "Height": 165, "...
# 1697  "Ages": 40, "Gender": "Male", "Height": 166, "...
# 1698  "Ages": 54, "Gender": "Female", "Height": 198,...
#
# [1698 rows x 1 columns]

# %%
df
# Out:
#                                                    Text
# 1     "Ages": 25, "Gender": "Male", "Height": 180, "...
# 2     "Ages": 32, "Gender": "Female", "Height": 165,...
# 3     "Ages": 48, "Gender": "Male", "Height": 175, "...
# 4     "Ages": 55, "Gender": "Female", "Height": 160,...
# 5     "Ages": 62, "Gender": "Male", "Height": 170, "...
# ...                                                 ...
# 1694  "Ages": 53, "Gender": "Female", "Height": 182,...
# 1695  "Ages": 38, "Gender": "Male", "Height": 150, "...
# 1696  "Ages": 57, "Gender": "Male", "Height": 165, "...
# 1697  "Ages": 40, "Gender": "Male", "Height": 166, "...
# 1698  "Ages": 54, "Gender": "Female", "Height": 198,...
#
# [1698 rows x 1 columns]

# %%
df['Title'] = df.index.astype(str)

# %%
df
# Out:
#                                                    Text Title
# 1     "Ages": 25, "Gender": "Male", "Height": 180, "...     1
# 2     "Ages": 32, "Gender": "Female", "Height": 165,...     2
# 3     "Ages": 48, "Gender": "Male", "Height": 175, "...     3
# 4     "Ages": 55, "Gender": "Female", "Height": 160,...     4
# 5     "Ages": 62, "Gender": "Male", "Height": 170, "...     5
# ...                                                 ...   ...
# 1694  "Ages": 53, "Gender": "Female", "Height": 182,...  1694
# 1695  "Ages": 38, "Gender": "Male", "Height": 150, "...  1695
# 1696  "Ages": 57, "Gender": "Male", "Height": 165, "...  1696
# 1697  "Ages": 40, "Gender": "Male", "Height": 166, "...  1697
# 1698  "Ages": 54, "Gender": "Female", "Height": 198,...  1698
#
# [1698 rows x 2 columns]

# %%
# Get the embeddings of each text and add to an embeddings column in the dataframe

model = 'models/embedding-001'
def embed_fn(title, text):
  return genai.embed_content(model=model,
                             content=text,
                             task_type="retrieval_document",
                             title=title)["embedding"]


df['Embeddings'] = df.apply(lambda row: embed_fn(row['Title'], row['Text']), axis=1)
df
# Out:
#                                                    Text Title  \
# 1     "Ages": 25, "Gender": "Male", "Height": 180, "...     1
# 2     "Ages": 32, "Gender": "Female", "Height": 165,...     2
# 3     "Ages": 48, "Gender": "Male", "Height": 175, "...     3
# 4     "Ages": 55, "Gender": "Female", "Height": 160,...     4
# 5     "Ages": 62, "Gender": "Male", "Height": 170, "...     5
# ...                                                 ...   ...
# 1694  "Ages": 53, "Gender": "Female", "Height": 182,...  1694
# 1695  "Ages": 38, "Gender": "Male", "Height": 150, "...  1695
# 1696  "Ages": 57, "Gender": "Male", "Height": 165, "...  1696
# 1697  "Ages": 40, "Gender": "Male", "Height": 166, "...  1697
# 1698  "Ages": 54, "Gender": "Female", "Height": 198,...  1698
#
#                                              Embeddings
# 1     [0.0030266906, -0.008476619, -0.044675007, -0....
# 2     [0.009257302, 0.0007417661, -0.038306423, -0.0...
# 3     [0.008448843, 0.0029076363, -0.038388327, -0.0...
# 4     [0.013579629, -0.0016232682, -0.043363273, -0....
# 5     [0.0037556323, 0.015628109, -0.0420066, -0.032...
# ...                                                 ...
# 1694  [0.012902935, 0.004273881, -0.0486263, -0.0408...
# 1695  [0.019779664, 0.0104915835, -0.04268414, -0.01...
# 1696  [0.0169689, 0.012871087, -0.04702588, -0.02512...
# 1697  [0.014956241, 0.0091882795, -0.043393888, -0.0...
# 1698  [0.025211481, 0.000704936, -0.046580367, -0.02...
#
# [1698 rows x 3 columns]

# %%
df.to_csv("embedding.csv")

# %%
df.head()
# Out:
#                                                 Text Title  \
# 1  "Ages": 25, "Gender": "Male", "Height": 180, "...     1
# 2  "Ages": 32, "Gender": "Female", "Height": 165,...     2
# 3  "Ages": 48, "Gender": "Male", "Height": 175, "...     3
# 4  "Ages": 55, "Gender": "Female", "Height": 160,...     4
# 5  "Ages": 62, "Gender": "Male", "Height": 170, "...     5
#
#                                           Embeddings
# 1  [0.0030266906, -0.008476619, -0.044675007, -0....
# 2  [0.009257302, 0.0007417661, -0.038306423, -0.0...
# 3  [0.008448843, 0.0029076363, -0.038388327, -0.0...
# 4  [0.013579629, -0.0016232682, -0.043363273, -0....
# 5  [0.0037556323, 0.015628109, -0.0420066, -0.032...

# %% [markdown]
# Use the `find_best_passage` function to calculate the dot products, and then sort the dataframe from the largest to smallest dot product value to retrieve the relevant passage out of the database.

# %%
def find_best_passage(query, dataframe):
  """
  Compute the distances between the query and each document in the dataframe
  using the dot product.
  """
  query_embedding = genai.embed_content(model=model,
                                        content=query,
                                        task_type="retrieval_query")
  dot_products = np.dot(np.stack(dataframe['Embeddings']), query_embedding["embedding"])
  idx = np.argmax(dot_products)
  return dataframe.iloc[idx]['Text'] # Return text from index with max value

# %%
def find_best_passage2(query, dataframe):
    """
    Compute the cosine similarity between the query and each document in the dataframe.
    Returns the most similar text.
    """
    # Generate query embedding
    query_embedding = genai.embed_content(
        model=model,
        content=query,
        task_type="retrieval_query"
    )["embedding"]
    
    # Convert list of embeddings to numpy array
    doc_embeddings = np.stack(dataframe['Embeddings'])  # Shape: (n_docs, embedding_dim)
    
    # Normalize embeddings (L2 normalization)
    doc_embeddings_norm = doc_embeddings / np.linalg.norm(doc_embeddings, axis=1, keepdims=True)
    query_embedding_norm = query_embedding / np.linalg.norm(query_embedding)  # Normalize query
    
    # Compute cosine similarity
    cosine_similarities = np.dot(doc_embeddings_norm, query_embedding_norm)
    
    # Get the index of the highest similarity
    idx = np.argmax(cosine_similarities)
    
    return dataframe.iloc[idx]['Text']  # Return text from the best-matching passage

# %%
import random

def find_best_passage3(query, dataframe, top_k=3, noise_factor=0.01):
    """
    Compute the cosine similarity between the query and each document in the dataframe,
    with a bit of randomness for more accurate and diverse results.
    """
    model1 = genai.GenerativeModel('gemini-1.5-pro-latest')
    a1 = model1.generate_content(f'''Convert the following user query into a structured JSON format with specified fields:

User Query: "{query}"

The output should include:
- **Personal Information**: Age, Gender, Height, Weight, Activity Level, Dietary Preference.
- **Nutrition Targets**: Daily Calorie Target, Protein, Sugar, Sodium, Carbohydrates, Fiber, Fat.
- **Health Condition**: Disease or dietary focus.

Ensure the format matches the example structure and do not enter any commnets etc andmentioin 0 if any daat is not devicable:
"
  "Ages": 25,
  "Gender": "Male",
  "Height": 180,
  "Weight": 80,
  "Activity Level": "Moderately Active",
  "Dietary Preference": "Omnivore",
  "Daily Calorie Target": 2000,
  "Protein": 120,
  "Sugar": 125.0,
  "Sodium": 24.0,
  "Calories": 2020,
  "Carbohydrates": 250,
  "Fiber": 30.0,
  "Fat": 60,
  "Disease": "Weight Gain""
'''
)
    model = 'models/embedding-001'
    # Generate query embedding
    print(a1.text)
    query_embedding = genai.embed_content(
        model=model,
        content=a1.text,
        task_type="retrieval_query"
    )["embedding"]
    
    # Convert list of embeddings to NumPy array
    doc_embeddings = np.stack(dataframe['Embeddings'])  # Shape: (n_docs, embedding_dim)
    
    # Normalize embeddings (L2 normalization)
    doc_embeddings_norm = doc_embeddings / np.linalg.norm(doc_embeddings, axis=1, keepdims=True)
    query_embedding_norm = query_embedding / np.linalg.norm(query_embedding)  # Normalize query
    
    # Compute cosine similarity
    cosine_similarities = np.dot(doc_embeddings_norm, query_embedding_norm)
    
    # Introduce slight noise for randomness
    cosine_similarities += np.random.uniform(-noise_factor, noise_factor, size=cosine_similarities.shape)
    
    # Get top-k indices sorted by similarity
    top_k_indices = np.argsort(cosine_similarities)[-top_k:]  # Get top-k highest similarity scores
    
    # Randomly choose one from the top-k
    chosen_idx = random.choice(top_k_indices)
    
    return dataframe.iloc[chosen_idx]['Text']  # Return text from the selected index

# %% [markdown]
# View the most relevant document from the database:

# %%
passage = find_best_passage('"Ages": 12, "Gender": "Female", "Height": 175, "Weight": 95, "Activity Level": "Very Active", "Dietary Preference": "Omnivore"', df)
passage
# Out:
# '"Ages": 18, "Gender": "Female", "Height": 198, "Weight": 91, "Activity Level": "Extremely Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 3103, "Protein": 232, "Sugar": 155.0, "Sodium": 46.4, "Calories": 3095, "Carbohydrates": 310, "Fiber": 37.2, "Fat": 103, "Breakfast Suggestion": "Tofu scramble with veggies", "Breakfast Calories": 312.0, "Breakfast Protein": 29.0, "Breakfast Carbohydrates": 75.0, "Breakfast Fats": 28.0, "Lunch Suggestion": "Lentil soup with whole wheat bread", "Lunch Calories": 328.0, "Lunch Protein": 23.0, "Lunch Carbohydrates": 39.0, "Dinner Suggestion": "Vegetable stir-fry with brown rice", "Dinner Calories": 250.0, "Dinner Protein.1": 28.0, "Dinner Carbohydrates.1": 32.0, "Dinner Fats": 15.0, "Snack Suggestion": "Banana with peanut butter", "Snacks Calories": 210, "Snacks Protein": 5, "Snacks Carbohydrates": 30, "Snacks Fats": 9, "Disease": "Weight Gain", "Lunch Fats": 8'

# %%
passage = find_best_passage2('"Ages": 12, "Gender": "Female", "Height": 175, "Weight": 95, "Activity Level": "Very Active", "Dietary Preference": "Omnivore"', df)
passage
# Out:
# '"Ages": 18, "Gender": "Female", "Height": 198, "Weight": 91, "Activity Level": "Extremely Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 3103, "Protein": 232, "Sugar": 155.0, "Sodium": 46.4, "Calories": 3095, "Carbohydrates": 310, "Fiber": 37.2, "Fat": 103, "Breakfast Suggestion": "Tofu scramble with veggies", "Breakfast Calories": 312.0, "Breakfast Protein": 29.0, "Breakfast Carbohydrates": 75.0, "Breakfast Fats": 28.0, "Lunch Suggestion": "Lentil soup with whole wheat bread", "Lunch Calories": 328.0, "Lunch Protein": 23.0, "Lunch Carbohydrates": 39.0, "Dinner Suggestion": "Vegetable stir-fry with brown rice", "Dinner Calories": 250.0, "Dinner Protein.1": 28.0, "Dinner Carbohydrates.1": 32.0, "Dinner Fats": 15.0, "Snack Suggestion": "Banana with peanut butter", "Snacks Calories": 210, "Snacks Protein": 5, "Snacks Carbohydrates": 30, "Snacks Fats": 9, "Disease": "Weight Gain", "Lunch Fats": 8'

# %%
passage = find_best_passage3('diet for 60 years man', df)
passage
# Out:
# ```json
# {
#   "Ages": 60,
#   "Gender": "Male",
#   "Height": 0,
#   "Weight": 0,
#   "Activity Level": "0",
#   "Dietary Preference": "0",
#   "Daily Calorie Target": 0,
#   "Protein": 0,
#   "Sugar": 0,
#   "Sodium": 0,
#   "Calories":0,
#   "Carbohydrates": 0,
#   "Fiber": 0,
#   "Fat": 0,
#   "Disease": "0"
# }
# ```
# '"Ages": 75, "Gender": "Male", "Height": 197, "Weight": 112, "Activity Level": "Moderately Active", "Dietary Preference": "Omnivore", "Daily Calorie Target": 2738, "Protein": 101, "Sugar": 79.5, "Sodium": 20.2, "Calories": 1337, "Carbohydrates": 159, "Fiber": 19.08, "Fat": 33, "Breakfast Suggestion": "Egg and spinach wrap", "Breakfast Calories": 166.0, "Breakfast Protein": 16.41, "Breakfast Carbohydrates": 53.0, "Breakfast Fats": 13.05, "Lunch Suggestion": "Avocado and chickpea salad", "Lunch Calories": 388.0, "Lunch Protein": 19.8, "Lunch Carbohydrates": 12.1, "Dinner Suggestion": "Tofu and quinoa bowl", "Dinner Calories": 540.0, "Dinner Protein.1": 48.0, "Dinner Carbohydrates.1": 14.0, "Dinner Fats": 33.0, "Snack Suggestion": "Protein bar", "Snacks Calories": 250, "Snacks Protein": 8, "Snacks Carbohydrates": 30, "Snacks Fats": 12, "Disease": "Weight Gain, Hypertension, Heart Disease", "Lunch Fats": 9'

# %% [markdown]
# ## Question and Answering Application
#
# Let's try to use the text generation API to create a Q & A system. Input your own custom data below to create a simple question and answering example. You will still use the dot product as a metric of similarity.

# %%
def make_prompt(query, relevant_passage):
  escaped = relevant_passage.replace("'", "").replace('"', "").replace("\n", " ")
  prompt = textwrap.dedent("""You are a helpful and informative bot that answers questions using text from the reference passage included below. \
  However, you are talking to a non-technical audience, so be sure to break down complicated concepts and \
  strike a friendly and converstional tone. \
  just use this passage as an reference and generate dite plan and ignore the disease part depend more on passage for diet suggistions and dont mention any comments
  use diete plan used in passage only and dont explain just specift the dite plan
  QUESTION: '{query}'
  PASSAGE: '{relevant_passage}'

    ANSWER:
  """).format(query=query, relevant_passage=escaped)

  return prompt

# %%
prompt = make_prompt('diet for 60 years man', passage)
print(prompt)
# Out:
# You are a helpful and informative bot that answers questions using text from the reference passage included below.   However, you are talking to a non-technical audience, so be sure to break down complicated concepts and   strike a friendly and converstional tone.   just use this passage as an reference and generate dite plan and ignore the disease part depend more on passage for diet suggistions and dont mention any comments
#   use diete plan used in passage only and dont explain just specift the dite plan
#   QUESTION: 'diet for 60 years man'
#   PASSAGE: 'Ages: 75, Gender: Male, Height: 197, Weight: 112, Activity Level: Moderately Active, Dietary Preference: Omnivore, Daily Calorie Target: 2738, Protein: 101, Sugar: 79.5, Sodium: 20.2, Calories: 1337, Carbohydrates: 159, Fiber: 19.08, Fat: 33, Breakfast Suggestion: Egg and spinach wrap, Breakfast Calories: 166.0, Breakfast Protein: 16.41, Breakfast Carbohydrates: 53.0, Breakfast Fats: 13.05, Lunch Suggestion: Avocado and chickpea salad, Lunch Calories: 388.0, Lunch Protein: 19.8, Lunch Carbohydrates: 12.1, Dinner Suggestion: Tofu and quinoa bowl, Dinner Calories: 540.0, Dinner Protein.1: 48.0, Dinner Carbohydrates.1: 14.0, Dinner Fats: 33.0, Snack Suggestion: Protein bar, Snacks Calories: 250, Snacks Protein: 8, Snacks Carbohydrates: 30, Snacks Fats: 12, Disease: Weight Gain, Hypertension, Heart Disease, Lunch Fats: 9'
#
#     ANSWER:

# %% [markdown]
# Choose one of the Gemini content generation models in order to find the answer to your query.

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro
# models/gemini-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-vision-latest
# models/gemini-pro-vision
# models/gemini-1.5-pro-latest
# models/gemini-1.5-pro-001
# models/gemini-1.5-pro-002
# models/gemini-1.5-pro
# models/gemini-1.5-flash-latest
# models/gemini-1.5-flash-001
# models/gemini-1.5-flash-001-tuning
# models/gemini-1.5-flash
# models/gemini-1.5-flash-002
# models/gemini-1.5-flash-8b
# models/gemini-1.5-flash-8b-001
# models/gemini-1.5-flash-8b-latest
# models/gemini-1.5-flash-8b-exp-0827
# models/gemini-1.5-flash-8b-exp-0924
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/learnlm-1.5-pro-experimental

# %%
model1 = genai.GenerativeModel('gemini-1.5-pro-latest')
answer = model1.generate_content(prompt)

# %%
Markdown(answer.text)
# Out:
# Hey there!  For a 60-year-old man, aiming for a daily calorie target around 2738, here's a sample meal plan:
#
# *   **Breakfast:** Egg and spinach wrap
# *   **Lunch:** Avocado and chickpea salad
# *   **Dinner:** Tofu and quinoa bowl
# *   **Snack:** Protein bar

# %% [markdown]
# ## Next steps
#
# To learn how to use other services in the Gemini API, see the [Python quickstart](https://ai.google.dev/tutorials/python_quickstart).
#
# To learn more about how you can use embeddings, see these  other tutorials:
#
#  * [Anomaly Detection with Embeddings](https://ai.google.dev/gemini-api/tutorials/anomaly_detection)
#  * [Clustering with Embeddings](https://ai.google.dev/gemini-api/tutorials/clustering_with_embeddings)
#  * [Training a Text Classifier with Embeddings](https://ai.google.dev/gemini-api/tutorials/text_classifier_embeddings)
